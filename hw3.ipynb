# %% [markdown]
# # Домашнее задание № 3. Исправление опечаток

# %%
import re
from string import punctuation
punctuation += "«»—…“”"
from collections import Counter
import textdistance
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_distances
from tqdm.notebook import tqdm

# %% [markdown]
# ## 1. Доп. ранжирование по вероятности (3 балла)

# %% [markdown]
# Дополните get_closest_hybrid_match в семинаре так, чтобы из кандадатов с одинаковым расстоянием редактирования выбиралось наиболее вероятное.

# %% [markdown]
# Исходные функции

# %%
def get_closest_match_with_metric(text, lookup, topn=20, metric=textdistance.levenshtein):
    # Counter можно использовать и с не целыми числами
    similarities = Counter()
    
    for word in lookup:
        similarities[word] = metric.normalized_similarity(text, word) 
    
    return similarities.most_common(topn)

def get_closest_hybrid_match(text, X, vec, topn=3, metric=textdistance.damerau_levenshtein):
    candidates = get_closest_match_vec(text, X, vec, topn*4)
    lookup = [cand[0] for cand in candidates]
    closest = get_closest_match_with_metric(text, lookup, topn, metric=metric)
    
    return closest

def get_closest_match_vec(text, X, vec, topn=20):
    v = vec.transform([text])
    
    # вся эффективноть берется из того, что мы сразу считаем близость 
    # 1 вектора ко всей матрице (словам в словаре)
    # считать по отдельности циклом было бы дольше
    # вместо одного вектора может даже целая матрица
    # тогда считаться в итоге будет ещё быстрее
    
    similarities = cosine_distances(v, X)[0]
    topn = similarities.argsort()[:topn] 
    
    return [(id2word[top], similarities[top]) for top in topn]

def P(word, N=N):
    return vocab[word] / N

def predict_mistaken(word, vocab):
    return 0 if word in vocab else 1

# %% [markdown]
# Создать словарь и дистрибутивную матрицу

# %%
with open('wiki_data.txt', encoding='utf-8') as f:
    corpus = f.read()

vocab = Counter(re.findall('\w+', corpus.lower()))
N = sum(vocab.values())

word2id = list(vocab.keys())
id2word = {i:word for i, word in enumerate(vocab)}

vec = CountVectorizer(analyzer='char', max_features=10000, ngram_range=(1,3))
X = vec.fit_transform(vocab)

# %%
vocab.most_common(10)
# Out:
# [('в', 267296),
#  ('и', 147115),
#  ('на', 81926),
#  ('с', 61681),
#  ('года', 43894),
#  ('по', 37235),
#  ('году', 32197),
#  ('из', 29150),
#  ('был', 23293),
#  ('не', 23228)]

# %% [markdown]
# Обновлённая функция. Надо выбрать более вероятный (частотный) вариант в случаях типа следующего

# %%
get_closest_hybrid_match('пртер', X, vec)
# Out:
# [('партер', 0.8333333333333334),
#  ('портер', 0.8333333333333334),
#  ('партере', 0.7142857142857143)]

# %%
print('партер', P('партер'))
print('портер', P('портер')) #частотнее по корпусу
# Out:
# партер 1.3578314578124677e-06
# портер 3.1036147607142114e-06

# %%
def NEW_get_closest_hybrid_match(text, X, vec, topn=3, metric=textdistance.damerau_levenshtein):
    candidates = get_closest_match_vec(text, X, vec, topn*4)
    lookup = [cand[0] for cand in candidates]
    closest = get_closest_match_with_metric(text, lookup, topn, metric=metric)
    
    candidates_id = [0]
    the_closest = closest[0][1]
    for i in range(1, len(closest)):
        if closest[i][1] < the_closest:
            break
        elif closest[i][1] == the_closest:
            candidates_id.append(i)
        else:
            return 'Wrong input from get_closest_match_with_metric'
    
    most_probable = closest[candidates_id[0]]
    for i in range(1, len(candidates_id)):
        if P(closest[candidates_id[i]][0]) > P(most_probable):
            most_probable = closest[candidates_id[i]]
    
    return most_probable

# %%
NEW_get_closest_hybrid_match('пртер', X, vec)
# Out:
# ('портер', 0.8333333333333334)

# %% [markdown]
# Пример, когда первый кандидат самый близкий и не нужно переходить к частотности

# %%
get_closest_hybrid_match('сcолнце', X, vec)
# Out:
# [('солнце', 0.8571428571428572),
#  ('солнцем', 0.7142857142857143),
#  ('солнцев', 0.7142857142857143)]

# %%
NEW_get_closest_hybrid_match('сcолнце', X, vec)
# Out:
# ('солнце', 0.8571428571428572)

# %% [markdown]
# ## 2.  Symspell (7 баллов)

# %% [markdown]
# Реализуйте алгоритм Symspell. Он похож на алгоритм Норвига, но проще и быстрее. Он основан только на одной операции - удалении символа. Описание алгоритма по шагам:
#
# 1) Составляется словарь правильных слов
#
# 2) На основе словаря правильных слов составляется словарь удалений - для каждого правильного слова создаются все варианты удалений и создается словарь, где ключ - слово с удалением, а значение - правильное слово (!)
#
# 3) Для выбора исправления для слова с опечаткой генерируются все варианты удаления, из них выбираются те, что есть в словаре удалений, построенного на шаге 2. Слово с опечаткой заменяется на правильное слово, соответствующее варианту удаления
#
# 4) Если в словаре удалений есть несколько вариантов, то выбирается удаление, которому соответствует наиболее вероятное правильное слово
#
#
# Оцените качество полученного алгоритма теми же тремя метриками.

# %% [markdown]
# Словарь правильных слов (условно: по корпусу)

# %%
correct_vocab = set(i for i in vocab)

for i in list(correct_vocab)[:10]:
    print(i)
# Out:
# arne
# дьявола
# некадровым
# остриё
# артинские
# кардиналом
# телефоном
# авачинскую
# писаренко
# лягушачьи

# %% [markdown]
# Словарь удалений (только 1 удаление, длина слова не учитывается)

# %%
deletions_vocab = dict()
for w in correct_vocab:
    for char in w:
        deletions_vocab[w.replace(char, '')] = w

for i in list(deletions_vocab.items())[:10]:
    print(i)
# Out:
# ('rne', 'rune')
# ('ane', 'jane')
# ('are', 'arge')
# ('arn', 'arin')
# ('ьявола', 'дьявола')
# ('дявола', 'дьявола')
# ('дьвола', 'дьявола')
# ('дьяола', 'дьявола')
# ('дьявла', 'дьявола')
# ('дьявоа', 'дьявола')

# %% [markdown]
# Функция

# %%
def get_deletions(word):
    deletions = []
    for char in word:
        deletions.append(word.replace(char, ''))
    return deletions

def get_most_probable_word(candidates):    
    most_probable = candidates[0]
    for i in range(1, len(candidates)):
        if P(candidates[i]) > P(most_probable):
            most_probable = candidates[i]
    return most_probable

def get_corrected_word(word, correct_vocab, deletions_vocab):
    if predict_mistaken(word, correct_vocab) == False:
        return word
    else:
        candidates = []
        for i in get_deletions(word):
            if deletions_vocab.get(i):
                candidates.append(deletions_vocab.get(i))
        print(candidates)
        
        if len(candidates) == 0:
            return word
        elif len(candidates) == 1:
            return deletions_vocab.get(candidates[0])
        else:
            return get_most_probable_word(candidates)

# %% [markdown]
# Я постарался в точности реализовать алгоритм, описанный в задании. Но у меня сложилось впечатление, что там не совсем корректная  формулировка: "<...> 3) Для выбора исправления для слова с опечаткой генерируются все варианты УДАЛЕНИЯ (выделение моё) <...>" -- таким образом мы будем редактировать слова со ВСТАВКОЙ, например, "мосЮква" вместо "москва". Чтобы исправлять удаления, нужно было бы в рамках алгоритма ПОДСТАВЛЯТЬ во все возможные позиции все возможеные буквы: чтобы, например, из "мсква" получить "мОсква"

# %%
get_corrected_word('солонце', correct_vocab, deletions_vocab)
# Out:
# ['солнце', 'солнце', 'солонцы']
# 'солнце'

# %%
get_corrected_word('сонце', correct_vocab, deletions_vocab)
# Out:
# ['донце', 'синице', 'соней']
# 'соней'

# %% [markdown]
# Оценка качества

# %%
bad = open('sents_with_mistakes.txt', encoding='utf-8').read().splitlines()
true = open('correct_sents.txt', encoding='utf-8').read().splitlines()

# напишем функцию, которая будет сопоставлять слова в правильном и ошибочном варианте
# разобьем предложение по пробелам и удалим пунктуация на границах слов
def align_words(sent_1, sent_2):
    tokens_1 = sent_1.lower().split()
    tokens_2 = sent_2.lower().split()
    
    tokens_1 = [token.strip(punctuation) for token in tokens_1]
    tokens_2 = [token.strip(punctuation) for token in tokens_2]
    
    tokens_1 = [token for token in tokens_1 if token]
    tokens_2 = [token for token in tokens_2 if token]
    
    assert len(tokens_1) == len(tokens_2)
    
    return list(zip(tokens_1, tokens_2))

# %%
correct = 0
total = 0

total_mistaken = 0
mistaken_fixed = 0

total_correct = 0
correct_broken = 0

cashed = {}
for i in tqdm(range(len(true))):
    word_pairs = align_words(true[i], bad[i])
    for pair in word_pairs:
        # чтобы два раза не исправлять одно и тоже слово - закешируем его
        # перед тем как считать исправление проверим нет ли его в кеше
        
        predicted = cashed.get(pair[1], get_corrected_word(pair[1], correct_vocab, deletions_vocab))
        cashed[pair[1]] = predicted
        
        if predicted == pair[0]:
            correct += 1
        total += 1
        
        if pair[0] == pair[1]:
            total_correct += 1
            if pair[0] !=  predicted:
                correct_broken += 1
        else:
            total_mistaken += 1
            if pair[0] == predicted:
                mistaken_fixed += 1
# Out:
# HBox(children=(FloatProgress(value=0.0, max=915.0), HTML(value='')))
# []
# ['шпионском']
# ['гламурные']
# []
# ['slap', 'cape', 'clip', 'cola']
# []
# []
# ['эпоним']
# []
# ['язычка']
# ['олень', 'олень', 'олень', 'олень']
# []
# ['серую', 'серую']
# ['отсутствие', 'отсутствие']
# ['сеневая', 'фоновая', 'попсовая', 'сеневая', 'основах']
# []
# []
# ['карасо', 'набрано', 'карасо']
# ['общему']
# ['щекам', 'яцека', 'ящика']
# []
# ['предлагаю']
# ['сегодняшнее']
# ['дороше', 'хэрше', 'хэрше', 'хороле', 'хороши']
# ['выходных']
# ['лите', 'рате', 'ринне', 'рита']
# ['снялся']
# ['потому', 'панаму', 'потому', 'патами']
# ['пытаясь']
# ['чаше', 'алше']
# ['дуброве', 'дубравы']
# []
# []
# ['билетных']
# []
# ['торто', 'чомом', 'чтят', 'чомом', 'чтят']
# []
# ['модный']
# []
# ['дороше', 'хэрше', 'хэрше', 'хороле', 'хороши']
# []
# ['кормилица']
# ['участвовать', 'участвовать', 'участвовать']
# ['сенья', 'седая', 'средн']
# []
# []
# ['ответственность', 'ответственность', 'ответственность']
# []
# ['казнена']
# ['740']
# ['начального', 'начальные']
# ['залог', 'зажги']
# []
# []
# []
# ['легии', 'сего', 'силиг', 'осле']
# ['цветянка']
# []
# ['женщина']
# []
# []
# ['малолетними', 'малолетняя', 'малолетняя']
# ['наркомании']
# []
# []
# []
# ['молчал', 'молчал']
# ['молчи']
# ['барьер']
# []
# ['комментариев']
# ['ответственный', 'ответственный']
# ['отличный', 'галичный']
# ['чашкой', 'саякой']
# []
# []
# []
# ['рассчитаны']
# []
# ['веселились', 'веселились']
# ['расспрашивая', 'раскрашивая']
# []
# []
# ['гребенюк']
# ['цкк', 'цкк', 'цкк', 'цкк']
# []
# ['низводит']
# ['истмена', 'примена']
# []
# ['серебряные', 'серебряные']
# []
# ['штуках', 'штучки']
# ['расшифровать']
# ['самойло']
# ['чаще', 'овоще', 'вазе']
# ['наверное', 'наверное', 'наверное']
# []
# ['сынишка']
# ['покоями', 'покорит']
# ['чернь', 'чернь', 'чернь']
# []
# ['всв', 'яня', 'всв']
# ['стараясь']
# ['нато', 'нато', 'каков']
# []
# ['мурину', 'мурину']
# []
# ['никара']
# ['чернь', 'чернь', 'чернь', 'чернь']
# []
# ['сотовые', 'оптовые', 'половые', 'оптовые', 'понтонные', 'потовых']
# ['слюнных']
# []
# []
# ['перспектива']
# ['ратовала']
# []
# []
# []
# ['расчете', 'расчете', 'рассвете']
# ['коупом', 'якупи']
# ['ранено', 'санино', 'страто', 'страто', 'странн']
# []
# ['общей', 'вообще']
# ['пришлась']
# ['приветствуется', 'приветствуется', 'приветствуется', 'приветствуется']
# []
# []
# ['опасался', 'опасался', 'опасался']
# []
# ['себеж', 'сажая', 'слабал', 'себеж']
# []
# []
# ['раскидал', 'раскидал', 'раскидал']
# ['умные', 'цзуне']
# []
# ['сочувствующие']
# []
# ['ноев', 'деву', 'дров', 'двое']
# []
# []
# ['если', 'нгли', 'наси']
# []
# ['щелка', 'чешка', 'пчела']
# ['обросла', 'отослан']
# []
# ['естественно', 'естественно', 'естественно']
# []
# []
# ['обнимает']
# ['основные', 'основные']
# ['фриды', 'элиды']
# []
# []
# []
# ['координирует', 'координирует', 'координирует']
# ['движение', 'движении', 'движение', 'движение', 'движении']
# ['даёшь']
# ['стартер', 'кстати']
# ['рассказчик']
# ['переехал', 'придали', 'переехал']
# ['прочитали', 'прочитали']
# []
# []
# ['могло', 'могло']
# []
# ['написано', 'написано', 'написано']
# []
# ['пересказывать', 'пересказывать']
# ['забавно']
# ['хамзину']
# ['ясный', 'пятый', 'пьяны']
# ['вотка', 'фолка', 'фонта', 'фотики']
# ['стартер', 'кстати']
# ['торто', 'чомом', 'чтят', 'чомом', 'чтят']
# []
# []
# []
# ['напряги']
# ['казалась']
# []
# ['священнослужители']
# ['рядах', 'ряска']
# []
# []
# []
# []
# ['сирио', 'сымо', 'сыре']
# ['чаще', 'овоще', 'вазе']
# []
# ['оперой', 'перви']
# ['никара']
# ['угадать', 'угадать']
# ['стартер', 'кстати']
# []
# ['материй', 'материй', 'материке']
# ['попадала', 'отдел', 'отдел', 'отдел']
# ['чаще', 'овоще', 'вазе']
# []
# ['рсе', 'фет', 'фс6']
# ['общей', 'вообще']
# ['милчу', 'имолу', 'молчи']
# []
# ['надет']
# ['гулливера']
# ['смыли', 'самыми', 'самши', 'саумы']
# ['солеи', 'свети', 'своим', 'усвое']
# ['радости']
# []
# ['обидел', 'обители', 'обидети', 'обидел']
# []
# ['рекомендация', 'рекомендация']
# []
# ['удалить']
# ['одноклассниках']
# ['эгмонт', 'ремонт', 'рэймон']
# []
# ['расингу', 'траскин']
# ['пулю', 'слою', 'спою', 'спил']
# []
# ['чаще', 'овоще', 'вазе']
# ['снежинок']
# ['шо', 'еле', 'шо']
# []
# []
# []
# []
# ['калоче', 'карпое']
# []
# []
# []
# ['симптом']
# ['нажатия', 'зачатия']
# ['луковой', 'луковой']
# ['потому', 'пойму', 'плоту', 'потеем']
# ['разовое']
# ['берущая']
# ['пришлось']
# ['калоче', 'карпое']
# []
# []
# ['одноклассников']
# []
# []
# ['поморье', 'поморье']
# []
# ['профессор']
# []
# []
# []
# []
# []
# ['сегодняшние']
# []
# []
# []
# ['начального', 'начальные']
# ['сдружился']
# ['начальнике', 'начальницу']
# ['рассмотрим']
# ['акити', 'затее', 'заики', 'затее']
# ['контракт']
# ['потеряна', 'потеряна']
# []
# []
# ['брить', 'убить']
# ['ишкуру', 'мицуру']
# []
# ['коммунисты', 'коммунисты']
# []
# ['госдуму', 'гордым', 'гордым']
# ['сенья', 'седая', 'средн']
# []
# []
# ['ответственно', 'ответственно']
# ['чернь', 'чернь', 'чернь', 'чернь']
# ['весит', 'бежит', 'беста', 'берси']
# []
# ['шмона', 'можга']
# []
# ['рисуной', 'рисунка']
# ['малику']
# []
# []
# ['яркость']
# ['птицу', 'птицу', 'потоку', 'потоми']
# ['взывал']
# ['спасибо', 'спасибо']
# ['шмона', 'можга']
# []
# []
# ['сведущий']
# []
# ['чернь', 'чернь']
# ['общей', 'вообще']
# ['рсе', 'фет', 'фс6']
# ['ошибочно', 'ошибочно']
# ['опаздывал']
# ['сенья', 'седая', 'средн']
# ['страшно', 'страшно', 'страшно', 'страшно']
# []
# ['равняться']
# ['обозреватель', 'обогреватели']
# ['покроя']
# ['казнена']
# ['компания', 'компания']
# ['прекратит', 'превратят']
# ['марш', 'фриш', 'фаши', 'фарт']
# []
# ['путь', 'жеть', 'жгут']
# ['встретила', 'встретила']
# []
# []
# []
# ['следующей']
# ['залипания']
# []
# ['жайлау', 'салаку', 'скайла']
# []
# ['чаще', 'овоще', 'вазе']
# []
# ['организмы', 'организмы']
# []
# []
# ['обычно']
# ['долг', 'долг', 'долг', 'долг']
# ['альпы', 'залын', 'залпе']
# ['беглянку']
# ['серебряном', 'серебряном']
# []
# ['сенья', 'седая', 'средн']
# []
# []
# []
# []
# ['шо', 'еле', 'шо']
# ['реклам', 'реклам']
# []
# ['безупречное', 'безупречное']
# ['арена', 'рени', 'ранка', 'ранена', 'рени']
# []
# ['началом', 'скачало']
# []
# []
# []
# []
# ['симпатичный']
# ['всякий']
# ['прокул', 'продал']
# []
# []
# ['открыл', 'открыл']
# []
# []
# []
# ['подробный']
# []
# ['постинг', 'постигли', 'постинг']
# ['вечером', 'ветром', 'вечном']
# []
# ['отечественные', 'отечественные', 'отечественные']
# ['приятно']
# ['познакомила', 'познакомила']
# ['монастырь', 'монастырь']
# ['стартер', 'кстати']
# ['шульца', 'шульги']
# ['зимарины', 'зимарины']
# []
# []
# []
# []
# ['общей', 'вообще']
# ['ироду', 'своду', 'среду', 'сроку']
# []
# ['выходу']
# ['решает']
# []
# ['юным', 'олым', 'охнм', 'коны']
# []
# []
# ['голой', 'клей', 'корой', 'клей', 'колос']
# ['спрашивая']
# ['тью', 'чье', 'чат']
# ['естественно', 'естественно', 'естественно']
# ['естественно', 'естественно', 'естественно']
# []
# ['луизу', 'приз', 'плаза', 'пули']
# ['сочным', 'обычным']
# ['тпк']
# ['душит', 'сшиты', 'суита', 'сушат', 'сушки']
# ['естественно', 'естественно', 'естественно']
# ['протянулось', 'протянулось']
# ['естественно', 'естественно', 'естественно']
# ['загибается']
# ['спасибо', 'спасибо']
# ['начального', 'начальные']
# ['понимать', 'подумать']
# []
# ['предположительно', 'предположительно']
# []
# []
# ['хорошее', 'хорошее', 'хорошее']
# ['потому', 'помогу', 'потоку', 'потому']
# []
# []
# ['негодования']
# ['тро', 'его', 'нет']
# []
# ['вчерашний']
# ['сенья', 'седая', 'средн']
# []
# []
# ['очень', 'очень', 'очные']
# ['скучал', 'скучал']
# ['стартер', 'кстати']
# ['древка']
# ['16417']
# ['пояснить', 'объяснит']
# []
# []
# ['прицела', 'приезда']
# ['будище', 'чудища']
# []
# ['соберутся']
# ['некоторым']
# ['хрям', 'парам', 'паря']
# []
# ['сведущий']
# ['10215']
# ['матфею', 'материи']
# ['сенья', 'седая', 'средн']
# ['кеши', 'лечил', 'кеши']
# ['постарайтесь']
# []
# ['пройдя']
# []
# ['сумасшедшего']
# []
# ['чувствовалась', 'чувствовалась']
# ['норштейн', 'норштейн', 'норштейн']
# ['поссорилась', 'поссорилась']
# []
# []
# []
# ['уж', 'еле']
# []
# ['сначала', 'сначала']
# ['пластыря']
# []
# ['рюкзак', 'рюкзак']
# ['сотую', 'ночную', 'сотую']
# ['милчу', 'имолу', 'молчи']
# ['чаще', 'овоще', 'вазе']
# []
# ['можайка', 'мозаика']
# ['любеке', 'любоч', 'любоч']
# []
# []
# ['история', 'история', 'история']
# []
# []
# []
# ['основная', 'основная']
# ['набирала']
# []
# []
# []
# ['сэндсом', 'бандом', 'брэдом', 'бэндов']
# []
# ['пишите', 'пишите', 'пишите']
# []
# []
# []
# ['строятся', 'строятся']
# []
# ['приводу']
# ['расчет', 'расчет', 'рассвет']
# ['одетому', 'апотому', 'почетом']
# []
# ['эмоциональная', 'эмоциональная', 'эмоциональная', 'эмоциональная']
# []
# []
# ['будке']
# ['маринер']
# ['общей', 'вообще']
# ['естественно', 'естественно', 'естественно']
# []
# []
# ['долг', 'долг', 'долг', 'долг']
# ['тянули']
# []
# []
# []
# []
# ['привычка']
# ['менных', 'менных']
# []
# []
# []
# ['поузи', 'поузи']
# []
# []
# []
# ['чернь', 'чернь', 'чернь', 'чернь']
# ['сенья', 'седая', 'средн']
# []
# ['некоторые']
# ['божий', 'боями']
# []
# ['божий', 'боями']
# []
# []
# []
# []
# ['смешны']
# []
# ['аскер']
# []
# []
# []
# ['естественно', 'естественно', 'естественно']
# ['сжалились']
# ['озек', 'мазака', 'мохк', 'мозг']
# ['треснуто']
# ['началом', 'скачало']
# ['парусу', 'тарсе', 'тарсе']
# ['евно', 'евно', 'рессор']
# ['созерцал', 'созерцал']
# ['завтра', 'завтра']
# ['попробуй']
# ['совершенное']
# []
# []
# []
# ['стартер', 'кстати']
# []
# ['неделимые']
# ['маршруток']
# ['щитком', 'сбитом']
# ['придается']
# []
# []
# []
# ['горбатюк']
# []
# []
# []
# []
# []
# []
# []
# ['прикладывая']
# ['облику', 'логику']
# ['изувеченное', 'извлеченные']
# []
# ['следит', 'следит', 'следит']
# ['пассажирам']
# ['слежки']
# ['территорию', 'территорию', 'территорию', 'территорию']
# []
# []
# []
# ['надет']
# []
# []
# ['шо', 'еле', 'шо']
# []
# ['кодеками', 'кодексах']
# ['забери', 'забери']
# []
# ['подставив']
# ['официально', 'официально']
# []
# ['дороше', 'хэрше', 'хэрше', 'хороле', 'хороши']
# ['образовались']
# ['доброжелательных']
# ['чернь', 'чернь', 'чернь']
# ['наказанными']
# []
# []
# ['общей', 'вообще']
# []
# []
# ['общему']
# []
# ['практических']
# []
# []
# ['естественно', 'естественно', 'естественно']
# []
# ['похожую']
# []
# ['пятью', 'лаять']
# ['годная', 'сводня']
# []
# ['нато', 'нато', 'каков']
# []
# ['купере', 'кулар', 'кулар']
# []
# ['чернь', 'чернь', 'чернь', 'чернь']
# ['холодная', 'холодная', 'холодная', 'холодная']
# ['гостиная', 'гостиная']
# ['чаще', 'овоще', 'вазе']
# []
# []
# []
# []
# ['надет']
# []
# ['евно', 'евно', 'рессор']
# []
# ['насчет', 'узнает', 'значит', 'значке']
# []
# []
# ['медал', 'кидали', 'скеда']
# []
# []
# []
# []
# ['предлагаю', 'предлагаю']
# ['равняться']
# ['оказаться', 'оказаться']
# ['вехи', 'выми']
# ['юнда', 'лода', 'люфа', 'блюд']
# ['чернь', 'чернь', 'чернь']
# []
# ['велю', 'цилю', 'ценю', 'цели']
# []
# []
# []
# []
# []
# ['пекарский']
# []
# ['педру', 'цедры']
# ['рушить', 'судить']
# ['стартер', 'кстати']
# []
# []
# []
# []
# []
# ['соратниками']
# []
# []
# []
# []
# []
# []
# ['дороше', 'хэрше', 'хэрше', 'хороле', 'хороши']
# ['провинция', 'провинция', 'провинция']
# ['скульптур']
# []
# []
# []
# ['дочь', 'мечь', 'мощь', 'мочи']
# []
# ['сделать', 'заделать']
# ['настоящий']
# ['тро', 'его', 'нет']
# ['кешей', 'вшей', 'вещей', 'вшей', 'внешне']
# ['общая']
# ['чернь', 'чернь', 'чернь', 'чернь']
# ['хаки', 'хаки']
# ['кощунство']
# ['способностью']
# ['несколько', 'несколько']
# ['территория']
# []
# []
# ['орсов', 'годов', 'госпо']
# ['день', 'спесь', 'день']
# ['развиться']
# ['осложнено', 'осложнено', 'осложнён']
# ['программка']
# []
# ['подорванная']
# []
# ['выразился', 'выродился']
# []
# ['старый', 'старый', 'старый']
# ['пройдя', 'прийде']
# ['ирокез', 'шираке']
# ['тро', 'его', 'нет']
# ['прикол']
# []
# []
# ['въехал']
# ['садовой']
# []
# []
# []
# ['натянуты']
# ['половозрелые']
# []
# ['естественно', 'естественно', 'естественно']
# []
# ['лабы', 'лабы']
# ['чернь', 'чернь', 'чернь']
# ['общей', 'вообще']
# []
# ['улиты', 'рубит', 'рулят', 'рубли']
# ['тро', 'его', 'нет']
# ['тро', 'его', 'нет']
# ['обычные']
# ['негодных']
# ['засчитан', 'рассчитан']
# ['люблю', 'алааб', 'алааб']
# ['зефир', 'кебир']
# ['опель', 'оплата', 'опель']
# ['очень', 'кочкин']
# []
# ['потратить', 'потратить', 'потратить', 'потратить']
# ['расчетов', 'расчетов']
# ['неприглядна']
# []
# ['нато', 'нато', 'каков']
# ['чаще', 'овоще', 'вазе']
# []
# []
# ['крепка', 'штепа', 'трипа', 'стресса', 'тремп']
# ['накрыт']
# ['шальные', 'реальны']
# []
# []
# []
# ['пройдя', 'прийде']
# ['рачков', 'сучков', 'исаков', 'скачков', 'сачком']
# ['сольно', 'сольно', 'сколько']
# ['таиланде']
# []
# []
# []
# []
# ['сняться']
# []
# ['сжечь', 'степь', 'стерч']
# ['окрестными']
# ['ссорится']
# ['правоту']
# []
# ['день', 'спесь', 'день']
# []
# ['нотки', 'фокич', 'фотию', 'фотики']
# []
# []
# ['рать', 'четь', 'чань', 'учат']
# ['лоток', 'фотон']
# ['халил', 'залила', 'зави', 'залили', 'зави']
# ['тро', 'его', 'нет']
# ['общей', 'вообще']
# []
# ['обмороженных']
# []
# []
# []
# ['нившера']
# ['отправную']
# ['овечку', 'отмечу']
# []
# ['простите', 'простите']
# ['начали', 'начатии', 'начали']
# []
# []
# ['стартер', 'кстати']
# ['убеждена']
# ['полетим', 'полетим']
# ['скайла', 'сказала', 'сказала']
# []
# ['родителем', 'родителем']
# ['светлую', 'советуют', 'советуя']
# ['общей', 'вообще']
# ['асибэ', 'пасли']
# ['сенья', 'седая', 'средн']
# ['ранкина', 'равнин', 'равнин']
# ['пряной', 'перино']
# ['талыми', 'старым']
# []
# ['сейчас']
# []
# []
# []
# ['поэтому', 'поэтому', 'поэтому']
# ['познают', 'понимаю']
# ['тоды', 'четы', 'чтоб']
# ['насти']
# []
# []
# []
# ['заля']
# []
# []
# ['начального', 'начальные']
# ['папуорт']
# ['сенья', 'седая', 'средн']
# []
# []
# []
# ['дему', 'джем', 'ждём', 'жаде']
# []
# []
# []
# []
# ['солнце', 'солнце']
# ['сенья', 'седая', 'средн']
# []
# ['прямо', 'прямо']
# []
# []
# ['спасибо', 'пансион']
# []
# []
# ['конем', 'олдем', 'одними', 'бодне']
# []
# ['чернь', 'чернь', 'чернь']
# []
# ['насчет', 'узнает', 'значит', 'значке']
# ['пришлись', 'прилесье']
# ['подвозится']
# ['сенья', 'седая', 'средн']
# []
# ['символизируют']
# ['чернь', 'чернь']
# []
# ['лючки', 'галки', 'глюка']
# ['кодня', 'когтя', 'когда']
# ['мещанской']
# []
# []
# []
# ['лику', 'тетку', 'гелуг', 'елки']
# []
# ['балтики', 'банток', 'банток']
# ['разворачивал', 'разворачивал', 'разворачивал', 'разворачивал']
# ['сведущего', 'следящего']
# ['зевен', 'зевен', 'зевен']
# []
# ['исадиков']
# ['общей', 'вообще']
# []
# []
# ['казнено']
# []
# []
# ['пересмотра']
# ['результете', 'результете']
# ['гага', 'сооо', 'гага', 'сооо', 'гага']
# ['нахожу', 'захочу']
# []
# ['чаще', 'овоще', 'вазе']
# []
# []
# ['согда', 'погода', 'подан', 'програ']
# ['становиться']
# []
# []
# []
# []
# ['таху', 'мтхту', 'татсу', 'таху', 'тахте']
# ['стеллан']
# []
# []
# []
# []
# ['стально', 'стально']
# ['нищего', 'нищего']
# []
# ['искусстве', 'искусстве']
# ['года', 'года', 'кога', 'огдр']
# []
# []
# []
# []
# ['просмотре', 'просмотре']
# []
# ['чернь', 'чернь']
# ['торто', 'чомом', 'чтят', 'чомом', 'чтят']
# []
# ['нато', 'нато', 'каков']
# ['разовое']
# ['лескин', 'пекина', 'персин']
# ['получилась', 'получилась']
# []
# []
# ['рассматривает', 'рассматривает', 'рассматривает']
# []
# []
# ['удлиняют']
# ['тпк']
# ['чернь', 'чернь', 'чернь']
# []
# ['раскрытие', 'раскрытие']
# []
# ['нашли', 'нашхо']
# ['совсем', 'совсем', 'совсем']
# ['привольный']
# []
# ['сигаретных']
# []
# []
# ['мелькающими']
# ['предки', 'вредит', 'впереди', 'впредь']
# ['чернь', 'чернь', 'чернь']
# ['муцина', 'муцина']
# []
# ['нефти']
# []
# ['эгоистично']
# ['нелепое', 'нелепое']
# ['ногай', 'можга', 'миноги']
# ['праджа', 'праджа', 'прадана', 'праджа']
# []
# ['учительница']
# ['5ххх', '5ххх', '5ххх', '5ххх']
# []
# ['девчонка']
# []
# ['чернь', 'чернь']
# ['подала', 'проди', 'проди']
# ['путёвок', 'путевки', 'путевой']
# ['уайланд', 'тарланд']
# ['пейзажи']
# []
# ['поздравлял']
# []
# []
# ['день', 'спесь', 'день']
# []
# []
# ['раф', 'дуф', 'даб']
# ['нато', 'нато', 'каков']
# []
# ['охранки', 'охранки']
# ['непроницаемыми']
# ['клеевое', 'клеопе', 'клевер', 'клеевое']
# []
# ['мортир', 'сортиро', 'сотин', 'сотин']
# ['сенья', 'седая', 'средн']
# []
# ['отчаивался']
# ['чернь', 'чернь', 'чернь', 'чернь', 'чернь']
# ['сведущий']
# ['черепахи']
# []
# ['ольше', 'блаше', 'болен']
# ['дергач']
# ['нашли', 'нашхо']
# []
# ['помощник']
# ['корча', 'греча', 'горша', 'горяч']
# ['чаще', 'овоще', 'вазе']
# ['иззат']
# []
# ['дех']
# []
# ['тро', 'его', 'нет']
# []
# []
# ['репнина', 'леунина', 'лепида', 'лепида']
# ['пять', 'топь', 'топя']
# []
# ['реньё', 'хеньо', 'хрени']
# []
# []
# ['ужаса', 'нужны']
# []
# []
# []
# ['расчет', 'расчет', 'рассвет']
# []
# ['кровей']
# ['чугунном', 'чугунов']
# []
# ['общему']
# []
# ['кичо', 'начо', 'нидо']
# []
# []
# ['просмотр']
# ['вытей']
# ['лялько']
# ['тенюх', 'тенюх']
# []
# []
# []
# ['расчеты', 'расчеты', 'рассветы']
# []
# []
# ['нато', 'нато', 'каков']
# ['поощрительной', 'подозрительно']
# ['проверок']
# []
# []
# ['оресто', 'просто', 'просто', 'портов', 'просто']
# []
# ['счастлив', 'счастлив']
# ['засчитан', 'рассчитан']
# []
# ['рашье', 'рашье', 'рашье']
# ['президент', 'президент']
# []
# []
# ['поляне', 'потянут', 'поляне']
# []
# ['ниде', 'гаде', 'гнев', 'ганда']
# ['шмона', 'можга']
# ['программу']
# []
# []
# []
# ['говорит', 'горист']
# []
# []
# []
# []
# []
# ['нечаянно']
# []
# ['пространство']
# []
# []
# []
# ['гулять']
# ['проекты', 'переодетые', 'продукту']
# ['диабетиком']
# []
# ['лекарственные', 'лекарственные']
# []
# []
# []
# []
# []
# ['перекрестком']
# ['выпадает']
# ['зеза', 'ийа', 'ийа']
# ['день', 'спесь', 'день']
# []
# ['авиабилете']
# ['напротив', 'напротив']
# []
# ['стартер', 'кстати']
# []
# ['отбывший', 'остывшей']
# []
# []
# []
# []
# []
# ['встречен']
# ['коридоры', 'коридоры', 'коридоры']
# ['бросили', 'бродил', 'бродил']
# ['стоп', 'пято', 'писо', 'апсат']
# ['нотки', 'фокич', 'фотию', 'фотики']
# ['самусь']
# ['батон', 'обанос', 'обкаток', 'батон']
# ['торто', 'чомом', 'чтят', 'чомом', 'чтят']
# ['риццо']
# ['нз', '4х']
# ['кичо', 'начо', 'нидо']
# ['эксперт']
# []
# ['методологическое', 'методологическое', 'методологическое']
# []
# ['сенья', 'седая', 'средн']
# ['опухоли']
# []
# []
# []
# []
# []
# []
# ['рауля', 'рауля', 'мамилия']
# ['слать', 'слать']
# []
# ['симпатичный']
# ['смуглой']
# []
# ['обязательно', 'обязательно']
# ['послезавтра']
# ['тусовка', 'тусовка']
# ['открыла', 'открыла', 'отрекла']
# []
# ['четвертая']
# []
# ['остановились', 'остановились', 'остановились']
# ['этому', 'пойму', 'потому', 'питом']
# ['некоторые']
# ['откровенным']
# []
# ['синья', 'скина']
# ['ськин', 'хаски']
# []
# ['шмона', 'можга']
# ['батьки']
# []
# ['мота', 'можи']
# ['очередная', 'очередная']
# []
# []
# ['рассчитаны']
# []
# ['тудва', 'сосуда', 'отдаю']
# ['вызволил', 'вызволил']
# ['недавно']
# []
# ['торто', 'комом', 'китти', 'комом', 'китти']
# []
# ['литре', 'шитье', 'шлитте', 'шалит']
# []
# ['привязанности']
# ['кодня', 'когтя', 'когда']
# []
# []
# []
# []
# ['здесь']
# []
# ['реньё', 'хеньо', 'хрени']
# []
# []
# ['комендант', 'комендант']
# ['чрево', 'резко']
# ['подложку', 'подножки']
# ['стартер', 'кстати']
# ['маленьких']
# ['чтят', 'буя', 'уитти', 'буя']
# []
# ['цкий', 'хаки', 'ваци', 'шацк']
# ['сегодня']
# []
# []
# ['ознакомились']
# []
# ['уловке', 'улочки']
# []
# ['попадались']
# ['съездил']
# ['разделенный', 'разделенный', 'разделенный']
# ['могло', 'могло']
# ['столько']
# ['полагает']
# []
# ['осушение', 'смущение']
# []
# []
# ['кичо', 'начо', 'нидо']
# ['пятница', 'пятница']
# ['зеза', 'ийа', 'ийа']
# ['заварного', 'запасного']
# ['верха']
# ['веера']
# []
# []
# []
# ['сенья', 'седая', 'средн']
# []
# []
# ['требуют', 'требуя']
# ['порядочность']
# []
# ['естественно', 'естественно', 'естественно']
# ['лентяем']
# ['профессиональные', 'профессиональные']
# ['бая', 'какая', 'бая', 'каяк']
# []
# ['серетсе', 'брет', 'брет', 'брет']
# []
# []
# ['соответственно', 'соответственно']
# []
# []
# []
# ['направлению', 'направлению']
# []
# []
# []
# ['общей', 'вообще']
# []
# ['журналисты']
# []
# ['переворот']
# ['некоторые']
# []
# ['чернь', 'чернь', 'чернь', 'чернь', 'чернь']
# []
# []
# []
# ['завтра']
# ['полночь']
# []
# ['однокурсник', 'однокурсник']
# ['неожиданно', 'неожиданно']
# ['мигрени', 'морены', 'морген', 'могреб']
# ['базируется']
# ['самусь']
# []
# ['купаться']
# ['торто', 'чомом', 'чтят', 'чомом', 'чтят']
# []
# ['общей', 'вообще']
# ['сходили', 'сходили']
# []
# ['килль', 'силлы', 'соки', 'соки']
# []
# ['сенья', 'седая', 'средн']
# []
# ['шапочки']
# []
# []
# ['тофу', 'тьму']
# ['сенья', 'седая', 'средн']
# []
# []
# ['вят', 'вят', 'вят']
# ['стартер', 'кстати']
# ['лоток', 'фотон']
# []
# ['2мя']
# []
# ['малаги', 'флаги', 'флаги']
# ['433я']
# ['отрезан', 'обрезано', 'отрезной', 'отрезан']
# []
# []
# []
# ['зеза', 'ийа', 'ийа']
# []
# ['лучей', 'глуше']
# []
# ['спеце', 'серет']
# []
# ['недобрых']
# []
# ['одона', 'онаго', 'одако', 'модно', 'одона']
# ['бовио', 'лвин', 'лоби', 'лобов']
# []
# []
# []
# ['палку', 'параку']
# []
# []
# []
# ['сделать', 'заделать']
# []
# []
# []
# ['разовое']
# []
# ['последний']
# ['gep']
# ['4239']
# ['стартер', 'кстати']
# ['титов', 'титов', 'григор']
# ['транспортная']
# ['парализована', 'парализована']
# []
# ['продолжение']
# ['торт', 'цчо', 'чтят', 'цчо']
# ['торто', 'чомом', 'чтят', 'чомом', 'чтят']
# []
# ['чернь', 'чернь', 'чернь']
# []
# ['безысходность']
# ['нельзя', 'нельзя']
# ['продать', 'прощает']
# []
# ['схи', 'яёи', 'ясь']
# []
# []
# ['чернь', 'чернь', 'чернь', 'чернь', 'чернь']
# ['плодовиты']
# []
# []
# ['сенья', 'седая', 'средн']
# []
# ['сенья', 'седая', 'средн']
# ['вешать', 'вещают']
# []
# ['террористы']
# ['чернь', 'чернь', 'чернь', 'чернь']
# []
# ['помахать']
# ['претендент']
# ['чернь', 'чернь', 'чернь', 'чернь', 'чернь']
# []
# ['проклятые', 'проклятые', 'проклятые', 'проклятые']
# ['баржи', 'баржи', 'буржуа']
# ['корить', 'мочить', 'мортье', 'морита']
# []
# ['объяснил']
# ['скачанных']
# []
# ['стейт', 'дядей', 'ясен']
# []
# ['ньивер', 'уивера', 'унверт']
# ['ведомости']
# ['чернь', 'чернь', 'чернь']
# ['создавалась', 'создавалась']
# ['сенья', 'седая', 'средн']
# ['азербайджан']
# ['узбекам']
# ['перино', 'притон', 'притон']
# []
# []
# []
# ['путь', 'жеть', 'жгут']
# ['чаще', 'овоще', 'вазе']
# []
# []
# []
# ['урадские', 'муромские']
# []
# ['йзер', 'юнер', 'юзмр', 'тюзе']
# []
# []
# []
# ['хирурга']
# ['тирайне']
# ['алексанян', 'алексанян']
# []
# []
# ['посмотрела', 'посмотрела']
# ['булакан', 'бурлюк', 'бурлюк']
# []
# ['самый', 'самый', 'самый']
# []
# ['издать', 'ведать', 'видеть', 'видаль']
# ['придается']
# ['портов']
# []
# []
# []
# []
# []
# []
# []
# ['пометы', 'примет']
# ['стартер', 'кстати']
# ['дм3', 'реем', 'дм3', 'седе']
# []
# []
# []
# []
# ['гума', 'буйба']
# []
# []
# ['продвигалась', 'продвигалась']
# ['чернь', 'чернь', 'чернь']
# ['гатов', 'аббатов', 'гатов', 'агаков', 'агатой']
# ['продолжение']
# ['тащусь', 'тащусь']
# ['можешь', 'сможет']
# []
# []
# ['спасибо']
# ['брендам', 'френдом']
# []
# ['соответственно', 'соответственно']
# ['общей', 'вообще']
# ['маршрут', 'маршруту', 'маршрут']
# ['вазе', 'вазе']
# []
# ['измываться']
# ['неопределенно', 'неопределенно', 'неопределенно', 'неопределенно']
# ['неопределенно', 'неопределенно', 'неопределенно', 'неопределенно', 'неопределенно']
# ['продолжено', 'продолжено']
# ['четь', 'дочь', 'отчет']
# []
# ['одноклассники']
# ['давидс', 'завес']
# []
# []
# []
# []
# []
# []
# ['расстоянии']
# ['торто', 'комом', 'китти', 'комом', 'китти']
# ['умудрился']
# ['мрачно']
# ['чаше', 'алше']
# []
# ['жеть', 'выть', 'верь', 'вент']
# []
# []
# []
# []
# ['противоречие']
# []
# []
# []
# ['накатило']
# []
# []
# ['кверху', 'наверх']
# ['поддерживает']
# []
# ['проявить', 'справить']
# []
# []
# []
# ['сенья', 'седая', 'средн']
# []
# ['милтон', 'мильян']
# ['чаще', 'овоще', 'вазе']
# ['варище', 'варище']
# []
# ['тетрь', 'терье', 'тень', 'тьер']
# ['началом', 'скачало']
# ['завтра']
# []
# []
# []
# ['иззат']
# []
# []
# []
# ['чаще', 'овоще', 'вазе']
# ['отлично', 'гатлинга', 'отлично']
# []
# []
# []
# ['потому', 'помогу', 'потоку', 'потому']
# []
# ['шмона', 'можга']
# ['организме']
# ['первый', 'первый', 'плевры']
# []
# ['смежной']
# []
# []
# ['латной', 'важной', 'вахтой']
# ['навеяно', 'наверное']
# []
# []
# ['кампе', 'копен', 'комет', 'компу']
# []
# ['ответственность', 'ответственность', 'ответственность', 'ответственность', 'ответственность']
# ['саумы', 'обамы', 'космы', 'осады', 'осаму']
# []
# ['влетел', 'черте', 'черте']
# ['предстаители']
# ['рязань', 'рязань']
# []
# []
# ['чувству']
# ['кучек', 'лузе', 'лучи']
# []
# ['мота', 'можи']
# ['успокоился']
# ['кичо', 'начо', 'нидо']
# []
# ['младенца', 'младенца']
# ['открыл']
# ['акций', 'акций']
# ['миллиардер']
# ['маркала', 'маркала']
# ['иззат']
# []
# ['чудить', 'бурить']
# ['басками', 'лапками', 'власами']
# ['деля', 'орел', 'одал', 'роде']
# ['kg1', 'aeg', 'tak']
# []
# ['торто', 'чомом', 'чтят', 'чомом', 'чтят']
# []
# ['сенья', 'седая', 'средн']
# ['гиены']
# ['проза', 'послал', 'проза']
# []
# ['предлагаю', 'предлагаю', 'предлагаю']
# []
# ['казнена']
# []
# ['неколико']
# ['солидным']
# []
# ['кичо', 'начо', 'нидо']
# []
# ['общей', 'вообще']
# []
# ['почувствовала', 'почувствовала']
# []
# []
# []
# ['естественно', 'естественно', 'естественно']
# []
# ['довольствие']
# ['процветание']
# ['сенья', 'седая', 'средн']
# ['зеза', 'ийа', 'ийа']
# ['придается']
# ['чернь', 'чернь', 'чернь']
# ['потке', 'фоксес', 'флоте', 'фотики']
# []
# []
# []
# ['зевак', 'деаку', 'девка', 'девка']
# ['усиление', 'усиление']
# []
# []
# []
# []
# []
# []
# ['чаще', 'овоще', 'вазе']
# []
# []
# ['сенья', 'седая', 'средн']
# []
# ['поднесла', 'принесла', 'пронесли']
# []
# ['цкк', 'цкк', 'цкк', 'цкк']
# []
# []
# []
# ['чернь', 'чернь', 'чернь', 'чернь']
# []
# ['усиленно', 'усиленно']
# ['меп', 'мрп', 'оре']
# []
# ['общему']
# []
# []
# ['стартер', 'кстати']
# []
# ['актином', 'актином', 'катионом']
# ['любовь', 'любовь']
# []
# ['естественно', 'естественно', 'естественно']
# []
# []
# []
# []
# ['гусинка', 'бузинка']
# []
# ['понимать', 'обнимает']
# []
# ['натянутые', 'натянутом']
# ['зажгите']
# []
# ['тро', 'его', 'нет']
# []
# []
# []
# []
# ['вкусна', 'вкусна']
# ['общей', 'вообще']
# ['состояние', 'состояние', 'состояние']
# []
# ['осушаются', 'случаются', 'слушается']
# ['токе', 'тонэ']
# ['захотела']
# ['написать', 'написать']
# ['чернь', 'чернь', 'чернь', 'чернь', 'чернь']
# ['бутко', 'жуков']
# ['мио', 'мио']
# ['парения', 'парения']
# ['симери']
# []
# ['сведущий']
# ['обещав']
# ['тро', 'его', 'нет']
# ['открытки']
# ['чернь', 'чернь', 'чернь', 'чернь']
# ['следующий']
# []
# ['чаще', 'овоще', 'вазе']
# []
# ['котельное', 'отдельное']
# []
# ['надет']
# ['люблю', 'алааб', 'алааб']
# []
# ['естественно', 'естественно', 'естественно']
# []
# []
# []
# ['сбивает', 'сливать']
# ['рожка', 'уорка', 'шурка', 'урона', 'мурок']
# []
# ['баррикады']
# ['обещают']
# []
# []
# []
# ['алиной', 'алиной']
# ['чернь', 'чернь', 'чернь', 'чернь']
# []
# ['якопо', 'кормом', 'якопо']
# ['определяется']
# []
# ['сообщит', 'сообщит']
# ['нато', 'нато', 'каков']
# []
# ['наглость']
# ['позвонить']
# []
# ['пришлись']
# ['тварь', 'тварь', 'тварь']
# ['кичо', 'начо', 'нидо']
# []
# []
# ['монгол', 'можгой']
# []
# []
# []
# []
# []
# ['берти', 'буери', 'зубри', 'убеди', 'жубер']
# []
# ['ще', 'ще', 'ще']
# ['кыш', 'тиш', 'тым']
# []
# []
# ['давняя', 'давняя', 'давняя']
# []
# ['улыбнулась']
# []
# ['проблемная', 'проблемная']
# ['переехал', 'придали', 'переехал']
# ['рейковыми']
# []
# ['кончено']
# ['тудва', 'сосуда', 'отдаю']
# ['завтра']
# []
# ['называется']
# []
# ['рецепт']
# ['отечественное']
# ['мотель', 'мотель']
# []
# ['профилактика', 'профилактика', 'профилактика']
# []
# ['некоторые']
# ['скриншот', 'скриншот']
# []
# ['кранио', 'кранио']
# ['комнатке']
# ['чаще', 'овоще', 'вазе']
# []
# []
# []
# []
# ['шурю', 'кирю', 'куро']
# ['дорожке', 'пряжке', 'пряжке']
# ['охранки', 'охранки']
# []
# ['спрашивая']
# ['овоще', 'овоще', 'овоще']
# ['чернь', 'чернь', 'чернь']
# []
# []
# []
# ['непонятны']
# ['объяснил', 'объяснил']
# []
# ['день', 'спесь', 'день']
# []
# ['серебряные', 'серебряные']
# []
# []
# ['вылетал']
# []
# ['зеза', 'ийа', 'ийа']
# ['покажется']
# ['усун', 'касак', 'курку', 'усун', 'касак']
# ['нато', 'нато', 'каков']
# ['теперь', 'терень', 'теперь', 'теперь']
# ['божий', 'боями']
# []
# ['зан', 'юаню', 'зан']
# ['придается']
# ['знать']
# ['завтра']
# []
# []
# ['коломенское', 'коломенское', 'коломенское']
# ['потом', 'поймой', 'потом', 'потом']
# []
# []
# ['долг', 'долг', 'долг', 'долг']
# []
# []
# ['борово', 'борово']
# []
# ['впечатление', 'впечатление']
# ['соответственно', 'соответственно']
# ['8460']
# []
# ['горный', 'чёрный', 'чорний']
# []
# ['вернулась', 'вернулась', 'вернулась']
# ['рэд', 'рэд', 'рэд', 'раанана', 'рэд']
# []
# []
# ['возьмёшь']
# ['ответственность', 'ответственность', 'ответственность']
# ['напишет']
# []
# ['поливает']
# []
# []
# []
# ['планирует']
# ['развито']
# []
# ['стартер', 'кстати']
# []
# ['муцина', 'муцина']
# ['волчат', 'молчит']
# ['параллельно', 'параллельное', 'параллельно', 'параллельно']
# []
# ['рааф', 'штата', 'торт', 'рааф', 'торт']
# ['общей', 'вообще']
# []
# []
# []
# ['надет']
# []
# ['ногай', 'можга', 'миноги']
# []
# ['почувствовав', 'почувствовав', 'почувствовав']
# ['совершения']
# []
# ['lancia', 'blanc', 'blanc']
# ['полете']
# ['надет']
# ['укладываются']
# ['тормозные']
# ['которых']
# ['помощник']
# ['сегодняшней', 'сегодняшнюю']
# []
# []
# ['рискнул']
# ['общей', 'вообще']
# ['бабино', 'аммианом', 'бабино', 'бабино']
# ['чернь', 'чернь', 'чернь']
# []
# []
# ['равняться']
# []
# ['котка', 'котка', 'котка', 'котка']
# ['мягче']
# ['остановлюсь', 'становились']
# []
# ['объективно']
# ['торто', 'комом', 'китти', 'комом', 'китти']
# ['торто', 'комом', 'китти', 'комом', 'китти']
# ['торто', 'комом', 'китти', 'комом', 'китти']
# ['естественно', 'естественно', 'естественно']
# ['сенья', 'седая', 'средн']
# ['принципы', 'принципы', 'принципы']
# ['применял']
# ['срываясь']
# ['естественно', 'естественно', 'естественно']
# ['одиночество']
# ['блеклых']
# ['желанием']
# ['просмотре', 'промоутер', 'просмотра', 'просмотре']
# ['конакри', 'конакри', 'контракт']
# []
# ['естественно', 'естественно', 'естественно']
# ['нукдан', 'нужда', 'нуква']
# []
# ['ответьте', 'ответьте', 'ответьте', 'ответьте']
# ['арестуют', 'андресу']
# ['барракуд', 'барракуд']
# []
# ['созванивается']
# []
# ['естественно', 'естественно', 'естественно']
# []
# ['пробами', 'пробках']
# ['минута', 'минутами', 'минута']
# []
# []
# ['майлз']
# []
# ['следующая']
# []
# []
# ['нефте', 'ищете', 'хинт', 'инеем', 'хинт']
# ['кичо', 'начо', 'нидо']
# []
# []
# []
# ['шоколаду']
# ['придается']
# ['совпали', 'сорвали']
# []
# ['связывает']
# []
# []
# []
# ['гомпы', 'копты', 'кормы', 'компу']
# ['занятных']
# []
# ['матроны', 'матроны']
# []
# []
# ['очищенный']
# []
# ['хрям', 'парам', 'паря']
# []
# ['волнующей']
# ['евно', 'евно', 'рессор']
# ['чаще', 'овоще', 'вазе']
# []
# ['апотому']
# []
# ['делается', 'удаётся', 'удаётся']
# []
# ['дикому', 'некому', 'седому', 'редком']
# ['ароматы']
# ['штюбель']
# []
# ['сомбор', 'субури', 'сомбор']
# ['проверка', 'проверка']
# []
# []
# []
# []
# []
# ['написать', 'написать', 'написать']
# ['талу', 'сансу', 'талу', 'стаббс']
# ['иваня', 'алиня', 'ливен']
# []
# ['рыле', 'млке', 'мызе', 'мыла']
# []
# ['нарекает']
# []
# []
# ['кичо', 'начо', 'нидо']
# ['согда', 'погода', 'подан', 'програ']
# ['нато', 'нато', 'каков']
# ['хотело', 'хотело']
# ['учиться']
# ['великом', 'венском']
# []
# []
# []
# ['чернь', 'чернь', 'чернь']
# []
# ['чувствовать', 'чувствовать', 'чувствовать', 'чувствовать']
# ['согда', 'погода', 'подан', 'програ']
# []
# ['арара', 'цкк', 'цкк', 'цкк', 'арара']
# ['цкк', 'цкк', 'цкк', 'цкк']
# []
# []
# []
# ['вят', 'вят', 'вят', 'вят']
# []
# []
# []
# []
# ['стартер', 'кстати']
# []
# ['неуравновешен', 'неуравновешен']
# ['ченс', 'воен', 'отчет']
# ['центра']
# ['леса', 'влова', 'леса', 'влево']
# ['расскажут']
# ['покажу', 'покажу', 'покажу', 'покажу', 'покажу']
# []
# ['забегах']
# ['боулта']
# []
# ['радужным', 'радужное']
# ['маршруток']
# []
# []
# ['второй']
# ['2939']
# ['придается']
# ['некоторым', 'некоторым', 'некоторым', 'некоторому']
# ['действие', 'действие']
# []
# []
# ['день', 'спесь', 'день']
# ['сосной']
# ['мужчины']
# ['прямо', 'прямо']
# ['гугб', 'гугб']
# ['гугб', 'гугб']
# ['попадает', 'попадает', 'попадает']
# ['сизые', 'санные']
# []
# []
# ['пятью', 'лаять']
# ['будке']
# []
# ['обл', 'шубу', 'шов']
# ['расчет', 'расчет', 'рассвет']
# ['ефрем', 'брем', 'белем', 'брем', 'береа']
# ['кичо', 'начо', 'нидо']
# []
# ['мудрейший']
# []
# ['пуст', 'пуст']
# []
# ['почитала']
# ['прочитавший']
# []
# ['олень', 'олень']
# ['никуда']
# ['дерется']
# ['неожиданного', 'неожиданной', 'неожиданного']
# []
# []
# []
# []
# []
# []
# ['квартиру', 'квартиру', 'квартирке']
# []
# []
# []
# ['общей', 'вообще']
# []

# %%
print(correct/total)
print(mistaken_fixed/total_mistaken)
print(correct_broken/total_correct)
# Out:
# 0.8540270135067534
# 0.15838509316770186
# 0.04306879522223498

# %% [markdown]
# Результаты слабые, что ожидаемо при использованной упрощённой процедуре. Ниже пробую чуть усложнить процедуру

# %%
# если нужно не только удаления, но и вставки: функция из семинара

def get_edits(word):
    
    "Создаем кандидатов, которые отличаются на одну букву"
    
    letters    = 'йцукенгшщзхъфывапролджэячсмитьбюё'
    splits     = [(word[:i], word[i:])    for i in range(len(word) + 1)]
    
    deletes    = [L + R[1:]               for L, R in splits if R]
#     transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R)>1]
#     replaces   = [L + c + R[1:]           for L, R in splits if R for c in letters]
    inserts    = [L + c + R               for L, R in splits for c in letters]
    
    return set(deletes + inserts)

# %%
edits_vocab = dict()
for w in tqdm(correct_vocab):
    for edit in get_edits(w):
        if edit not in edits_vocab:
            edits_vocab[edit] = w
# Out:
# HBox(children=(FloatProgress(value=0.0, max=368802.0), HTML(value='')))

# %%
def NEW_get_corrected_word(word, correct_vocab, edits_vocab):
    if predict_mistaken(word, correct_vocab) == False:
        return word
    else:
        candidates = []
        for i in get_edits(word):
            if edits_vocab.get(i):
                candidates.append(edits_vocab.get(i))
        print(candidates)
        
        if len(candidates) == 0:
            return word
        elif len(candidates) == 1:
            return edits_vocab.get(candidates[0])
        else:
            return get_most_probable_word(candidates)

# %%
NEW_get_corrected_word('сонце', correct_vocab, edits_vocab)
# Out:
# ['сьоне', 'согне', 'сне', 'конце', 'монце', 'сионе', 'солнцем', 'слоне', 'донце', 'соц', 'конце', 'конце', 'сотне', 'соц', 'солнцев', 'сосне', 'сотне', 'сонет', 'монце', 'сонче', 'сонче', 'солнцев', 'донце', 'соней']
# 'конце'

# %% [markdown]
# Хотя "солнце" и не выбирается, по крайней мере оно теперь есть среди кандидатов

# %%
NEW_get_corrected_word('масква', correct_vocab, edits_vocab)
# Out:
# 'масква'

# %% [markdown]
# Такая замена не исправляется в соответствии с процедурой

# %%
NEW_get_corrected_word('солмце', correct_vocab, edits_vocab)
# Out:
# ['соломе', 'солнце', 'солнце', 'соломе', 'солнце']
# 'солнце'

# %% [markdown]
# А такая -- да

# %%
correct = 0
total = 0

total_mistaken = 0
mistaken_fixed = 0

total_correct = 0
correct_broken = 0

cashed = {}
for i in tqdm(range(len(true))):
    word_pairs = align_words(true[i], bad[i])
    for pair in word_pairs:
        # чтобы два раза не исправлять одно и тоже слово - закешируем его
        # перед тем как считать исправление проверим нет ли его в кеше
        
        predicted = cashed.get(pair[1], NEW_get_corrected_word(pair[1], correct_vocab, edits_vocab))
        cashed[pair[1]] = predicted
        
        if predicted == pair[0]:
            correct += 1
        total += 1
        
        if pair[0] == pair[1]:
            total_correct += 1
            if pair[0] !=  predicted:
                correct_broken += 1
        else:
            total_mistaken += 1
            if pair[0] == predicted:
                mistaken_fixed += 1
# Out:
# HBox(children=(FloatProgress(value=0.0, max=915.0), HTML(value='')))
# []
# ['шпионском', 'шпионской', 'шпионской', 'шпионской', 'шпионском']
# ['гламурные', 'гламурные', 'гламурным', 'гламурные', 'гламурным']
# []
# ['olap', 'clup', 'clan', 'camp']
# ['апофеозом', 'апофеозом', 'апофеозом']
# []
# ['эпоним', 'пони', 'пони']
# ['получается', 'получаются', 'получаться', 'получаться']
# ['язычка', 'язычке', 'язык', 'язычок', 'язык', 'язычники', 'язычники', 'язычка', 'язычке']
# []
# []
# ['сеют', 'сеют', 'сетует', 'советуют', 'сету', 'сетует', 'советуют', 'сету']
# ['отсутствием', 'отсутствием']
# ['новая', 'основах', 'носовая', 'основав', 'новая', 'тоновая', 'основания', 'фоновая', 'основ', 'основах', 'основав', 'основал', 'носовая', 'основал', 'основал', 'основам', 'основан', 'основан', 'основам']
# []
# []
# ['набрано', 'напрасной', 'напрасной', 'набрано', 'напрасное']
# ['вообще', 'общему', 'всеобщем', 'всеобщем', 'общему', 'обще']
# ['щекам', 'ящика', 'яцека', 'ящика', 'щенка', 'щелка', 'ящика', 'яцека', 'ека', 'щеках', 'ека']
# []
# ['предлагают', 'предаю', 'предлагают', 'предаю']
# []
# ['хорошему', 'хороша', 'дороше', 'хоре', 'хороле', 'хорошего', 'хорошеву', 'хорошо', 'хоре', 'хорошеву', 'хороша', 'хороша', 'хороши', 'хороши', 'хороле', 'роше', 'роше', 'хорошо', 'дороше']
# ['выходы', 'выходы', 'выходных', 'выходных']
# ['руте', 'рике', 'ризе', 'сите', 'арте', 'сите', 'ритейл', 'ритм', 'чите', 'фрит', 'ритэге', 'крит', 'лите', 'ригате', 'юристе', 'эрте', 'критек', 'орбите', 'рифе', 'лите', 'рита', 'роте', 'риттер', 'шарите', 'рибе', 'ризе', 'ригате', 'рише', 'рище', 'притче', 'рёте', 'рине', 'бритые', 'рише', 'христе', 'рике', 'рихе', 'ритм', 'курите', 'рифе', 'рихтер', 'дите', 'бритые', 'риге', 'крит', 'чите', 'риту', 'гите', 'крипте', 'итье', 'ре', 'ирбите', 'рёте', 'рита', 'итре', 'рихе', 'ре', 'щите', 'щите', 'роте', 'приюте', 'риты', 'инте', 'юристе', 'иврите', 'приюте', 'гите', 'риме', 'мите', 'риту', 'рате', 'орбите', 'ител', 'инте', 'дите', 'руте', 'причте', 'рище', 'рибе', 'мите']
# ['снится', 'снятия', 'снятая', 'снится', 'снизятся', 'снят', 'снится', 'снялся', 'снялся', 'снялся', 'снятая', 'снятая', 'снятия']
# ['патами', 'патуму', 'панаму', 'патуму', 'патами', 'пату', 'панаму', 'пату', 'панаму', 'патами', 'таму', 'таму']
# ['пытаясь', 'пытаясь', 'пытаясь']
# ['лучшие', 'ше', 'льше', 'лучшем', 'ше', 'чаше', 'лучшей', 'льше', 'че', 'алше', 'лучшее', 'лучшие']
# ['дубравы', 'дубравы', 'дубрава', 'дуброве', 'дубае', 'убрав', 'дубрава', 'дубравы', 'дуброве', 'дубае', 'дуброве']
# []
# []
# ['билетных', 'билетные', 'билетных', 'битным', 'билеты', 'битным', 'билетных', 'билетные']
# []
# ['тоо', 'тто', 'что', 'тотом', 'торто', 'что', 'тоо']
# []
# ['мощный', 'оный', 'модный', 'модный', 'мный', 'оный', 'мощный', 'моны']
# ['кредитно', 'кредитом', 'кредитно', 'кредитом', 'кредитов', 'кредит', 'кредитов']
# ['хорошему', 'хороша', 'дороше', 'хоре', 'хороле', 'хорошего', 'хорошеву', 'хорошо', 'хоре', 'хорошеву', 'хороша', 'хороша', 'хороши', 'хороши', 'хороле', 'роше', 'роше', 'хорошо', 'дороше']
# []
# ['кормилица', 'кормилица', 'кормили', 'кормилица']
# []
# ['беседня', 'беседня', 'сведя', 'ясеня', 'следя', 'средняя', 'сведя', 'седая', 'сегодня', 'средн', 'дня', 'сегодня', 'дня', 'сенья', 'седан', 'сенья', 'седан']
# []
# []
# ['ответственностью', 'ответственностью']
# ['пивовар', 'пивовар']
# ['канна', 'казнена', 'казнена']
# ['409']
# ['начальное', 'начальные', 'начальное']
# ['залог', 'зажёг', 'жог', 'зао', 'зажги', 'зажёг', 'жог', 'зажёг', 'залог', 'залог']
# ['взрослому', 'взрослому']
# ['предыдущую', 'предыдущую', 'предыдущую']
# ['прыщи', 'прыщи']
# ['се', 'сепг', 'олег', 'слгт', 'слегка', 'снег', 'сленге', 'йсле', 'лего', 'слегла', 'лего', 'силе', 'слуг', 'слегла', 'слез', 'сжег', 'сленге', 'сжег', 'наслег', 'сегу', 'слез', 'се', 'селе', 'снег', 'слеп', 'слог', 'слёг', 'слёг', 'слог', 'олег', 'слуг', 'слёг', 'слет', 'след', 'след', 'наслег']
# ['ветряная', 'цветянка', 'ветряная', 'цветянка']
# []
# ['женщина', 'ншина', 'женщина', 'женщина', 'ншина']
# []
# ['какие', 'какие']
# ['малолетним', 'малолетних', 'малолетним', 'малолетний', 'малолетний', 'малолетних', 'малолетних']
# ['наркоматы', 'наркомы', 'наркоматы', 'наркомана', 'наркомана', 'наркомана', 'наркоматы']
# []
# []
# []
# ['молла', 'молча', 'молчали', 'молла', 'молчали', 'молчали']
# ['молче', 'молчи', 'молча', 'молча', 'мою', 'молчи', 'мою', 'мол', 'молче']
# ['барьер', 'баркер', 'барбер', 'барр', 'барбер', 'барбер', 'баркер', 'барьер', 'баре']
# ['тото']
# []
# ['ответственны', 'ответственны']
# ['наличный', 'отличный', 'отличный', 'наличный', 'отличный', 'галичный', 'античный', 'античный']
# ['чашкой', 'саякой', 'шашкой', 'самкой', 'самкой', 'чашкой', 'шашкой', 'сако', 'ской', 'самкой', 'шашкой', 'саякой']
# ['тото']
# []
# []
# ['считаны', 'рассчитан', 'считаны', 'рассчитан']
# []
# ['вселились', 'вселились']
# ['спрашивая', 'раскрашивая', 'раскрашивая', 'раскрашивая', 'спрашивая']
# []
# []
# ['гребенская', 'гребенская', 'ребека', 'гребенюк', 'гребёнка', 'гребёнка', 'гребёнка', 'ребека', 'гребенюк']
# []
# []
# ['низводит', 'заводить', 'водить', 'водить', 'низводит', 'взводить', 'взводить']
# ['смена', 'пимен', 'исмен', 'смена', 'примена', 'истмена']
# ['супермаркет']
# []
# []
# ['штучками', 'штучки', 'штучки', 'штуках', 'штучки', 'штуках']
# ['расшифровать', 'расшифровать', 'расшифровать']
# ['самой', 'самойло', 'самой', 'сайто', 'самойло', 'сайто']
# ['ване', 'вале', 'варище', 'варище', 'чаще', 'вате', 'ваше', 'ве', 'вазе', 'ваке', 'чаще', 'ваге', 'вале', 'варе', 'вате', 'ва', 'чаще', 'васе', 'ваше', 'ваге', 'васе', 'ваке', 'ване', 'ваке', 'вазе']
# ['наверное', 'наверное', 'наверное', 'наверное']
# []
# ['сынишка', 'сынишка', 'сынишка']
# ['покорив', 'прокормит', 'покои', 'подкормки', 'покорил', 'прокорм', 'покормить', 'покорив', 'прокормит', 'подкормки', 'покоями', 'покоями']
# ['очень']
# ['делала', 'делала', 'делала']
# ['сия', 'ясь', 'ася', 'яса', 'ясо', 'свя', 'янс', 'яоя', 'сня', 'ясу', 'яоя', 'няя', 'свя', 'ясь', 'сян', 'вся', 'ясу', 'яоя', 'ляс', 'яслям', 'яслях', 'сяс', 'сюя', 'сяч', 'сея', 'яса', 'яслям', 'ася', 'вся', 'схя', 'ямс', 'сяс', 'ясу']
# ['стараясь', 'стараясь', 'стараясь']
# ['канто', 'кокто', 'актов', 'каско', 'катод', 'какой', 'факто', 'лакто', 'аркто', 'кайко', 'факто', 'какое', 'какао', 'какао', 'карто', 'катон', 'окато', 'канто', 'окато', 'какой', 'каток', 'каком', 'акт', 'кто', 'кокто', 'лакто', 'акт']
# []
# []
# ['заботила', 'заботила']
# ['нада', 'никандра', 'нада', 'никандра', 'никуда', 'икад', 'никара', 'никара', 'нида', 'никуда', 'икад']
# []
# []
# ['сотовые', 'оптовые', 'оптовые', 'ротовые', 'поветовые', 'потовых', 'потовых', 'оптовые', 'половые', 'готовые', 'ротовые', 'побитовые', 'половые', 'сотовые', 'ротовые', 'готовые', 'поветовые', 'половые', 'побитовые', 'потовых']
# ['слюнных', 'слюнных', 'слюне', 'слюнных', 'слюне']
# ['результаты', 'результаты', 'результаты']
# []
# ['перспектива', 'перспектива', 'перспектива']
# ['радовало', 'враждовала', 'радовало', 'порадовала', 'порадовала', 'ратовала', 'враждовала', 'ратовала', 'ратовала', 'радовало']
# ['приорат', 'приорат']
# []
# ['седели', 'съездили', 'съездили', 'седели', 'съезде', 'съездили', 'съезде']
# ['рассвете', 'расчет', 'рассвете', 'рассвете', 'расчет']
# ['купли', 'кум', 'купли', 'купив', 'купив', 'упи', 'кпи', 'купил', 'якупи', 'крупи', 'куи', 'купил']
# ['странное', 'сирано', 'ранено', 'странной', 'странном', 'рано', 'санино', 'санн', 'рано', 'странном', 'анно']
# ['како']
# ['обе', 'общее', 'общем', 'общ', 'общей', 'общие', 'вое', 'обе', 'обыще', 'овоще']
# ['пришлись', 'пришлось', 'прилесье', 'пришлись', 'прилесье', 'пришлось', 'пришлась', 'пришлась', 'пришлись']
# []
# []
# []
# ['опасался', 'опасался', 'опасался', 'опасался']
# ['сжился', 'сжился']
# ['слаба', 'стажа', 'сабба', 'сабан', 'саж', 'самба', 'снабжал', 'сабба', 'сажая', 'стажа', 'сабах', 'снабжал', 'сабац', 'сабах', 'аба']
# []
# []
# []
# ['заумные', 'цзуне', 'заумные', 'ные', 'цзуне', 'умные']
# []
# []
# []
# ['доде', 'ноев', 'боев', 'двое', 'девы', 'лоев', 'юдов', 'деев', 'юдов', 'дзгоев', 'дозе', 'доре', 'дево', 'деви', 'древ', 'джиоев', 'одоеву', 'диев', 'дзгоев', 'олев', 'лоев', 'ядов', 'дейв', 'дохе', 'доне', 'вдов', 'осев', 'гдов', 'доке', 'здев', 'одоева', 'деве', 'дцев', 'осев', 'одоева', 'древ', 'древ', 'ноев', 'боев', 'надоев', 'джиоев', 'деев', 'доце', 'доме']
# []
# []
# ['сели', 'нали', 'слиф', 'хенсли', 'снесли', 'внесли', 'юнли', 'анси', 'ясли', 'ясли', 'нгли', 'слив', 'носили', 'слик', 'нили', 'слит', 'нгли', 'унесли', 'ясли', 'инси', 'слои', 'нтли', 'нс', 'нтли', 'унесли', 'нсис', 'хенсли', 'нтли', 'нули', 'соли', 'носили', 'нали', 'нс', 'нули']
# ['экономик', 'экономиста', 'экономик', 'экономиста']
# ['шелка', 'чеках', 'черка', 'чешка', 'белка', 'чейка', 'щелка', 'чел', 'щелка', 'селка', 'чек', 'пчела', 'челнока', 'белка', 'черка', 'селка', 'селка', 'чешка', 'челнока', 'чейка', 'чек', 'чехла', 'шелка', 'чекан', 'чка']
# ['троса', 'отослав', 'обросла', 'отослал', 'троса', 'отослан', 'отослав', 'обросла', 'отбросила', 'обросла']
# ['стричь', 'стричь']
# ['естественной', 'естественной', 'естественном', 'естественное']
# ['слишком', 'слишком', 'слишком']
# []
# ['отнимает', 'обнимает', 'понимает', 'обнимает', 'отнимает', 'понимает']
# ['основны', 'основны']
# ['элиды', 'фриды', 'рид', 'эри', 'эгиды', 'элиды', 'эгиды', 'эры', 'эгиды', 'эры', 'фриды']
# ['тото']
# ['получатся', 'получатся']
# []
# []
# ['движением', 'движением']
# ['даёшь', 'делаешь', 'делаешь', 'даёшь', 'ешь', 'ешь', 'даш', 'даёшь', 'дае', 'думаешь', 'думаешь']
# ['кстати', 'костанте', 'статен', 'кате', 'сате', 'статей', 'костанте', 'сате', 'кстати', 'статье', 'кстати', 'старте', 'статуе', 'стае']
# ['рассказчики', 'рассказчику', 'рассказчика', 'рассказчика']
# ['порхали', 'придали', 'придали', 'приехал', 'приехал', 'порхали', 'приалит', 'приалит']
# ['почитал', 'прочитали', 'почитал', 'просчитал', 'просчитал', 'прочитала']
# ['удивлены', 'удивленный', 'удивленный', 'удивленный']
# ['нисхождение', 'нисхождение', 'нисхождение']
# ['наёмного', 'немногое', 'умного', 'наёмного', 'многом', 'многой', 'немногое', 'умного', 'ммного', 'многой', 'ммного', 'немого']
# ['открыв', 'открыв']
# ['написанного', 'написанному', 'написанного', 'написан', 'написанного', 'написанному', 'написан']
# []
# []
# ['забавно', 'забав', 'забавно', 'забан']
# ['храмину', 'храмину', 'храмину', 'ламин', 'хамзину', 'ламин']
# ['пляжный', 'ясный', 'пятый', 'явный', 'пляжный', 'пятый', 'яны', 'ный', 'пятый', 'явный', 'пьяны']
# ['лотка', 'фомка', 'котка', 'вотка', 'форта', 'лотка', 'тка', 'потка', 'фок', 'котка', 'фотад', 'откат', 'фонта', 'отека', 'фолка', 'отказ', 'отёка', 'фомка', 'фоска', 'лотка', 'фолка', 'форта', 'вотка', 'фокса', 'фоска', 'фомка', 'потка']
# ['кстати', 'костанте', 'статен', 'кате', 'сате', 'статей', 'костанте', 'сате', 'кстати', 'статье', 'кстати', 'старте', 'статуе', 'стае']
# ['тоо', 'тто', 'что', 'тотом', 'торто', 'что', 'тоо']
# []
# []
# []
# ['напряги', 'напряги', 'напрягает', 'напряги', 'напрягает']
# ['касалась', 'касалась', 'касалась', 'казалась', 'казалась']
# ['сосно', 'сосно']
# []
# ['рядах', 'рядах', 'рах', 'яса', 'ряска', 'яссах', 'яса', 'рядах']
# ['огромных', 'огромных']
# ['неосознанно', 'неосознанно', 'неосознанно', 'неосознанно', 'неосознанно']
# ['сохора', 'сохара', 'охра', 'сохр', 'охра', 'сора']
# []
# ['серо', 'сырной', 'сырной', 'сыра', 'стро', 'сырт', 'ясыров', 'сыру', 'сысо', 'стро', 'сымо', 'серо', 'сысо', 'сымо', 'сыру', 'ро', 'сыромя', 'со', 'соро', 'сыра', 'сыры', 'сыре', 'сырков', 'сыре', 'ясыров', 'сырт', 'соро', 'сиро', 'ср', 'сиро', 'со', 'сыромя', 'сыры', 'срок']
# ['ване', 'вале', 'варище', 'варище', 'чаще', 'вате', 'ваше', 'ве', 'вазе', 'ваке', 'чаще', 'ваге', 'вале', 'варе', 'вате', 'ва', 'чаще', 'васе', 'ваше', 'ваге', 'васе', 'ваке', 'ване', 'ваке', 'вазе']
# ['прежнему', 'прежнему', 'прежнему']
# ['пей', 'пей', 'перви', 'перво', 'перви', 'перво', 'прв', 'перво', 'перов']
# ['нада', 'никандра', 'нада', 'никандра', 'никуда', 'икад', 'никара', 'никара', 'нида', 'никуда', 'икад']
# ['гадает', 'гадает']
# ['кстати', 'костанте', 'статен', 'кате', 'сате', 'статей', 'костанте', 'сате', 'кстати', 'статье', 'кстати', 'старте', 'статуе', 'стае']
# ['когда', 'когда']
# ['марией', 'артерией', 'матрицей', 'артерией', 'материке', 'матери', 'матрицей', 'матери']
# ['отпадал', 'отдал', 'отдал']
# ['ване', 'вале', 'варище', 'варище', 'чаще', 'вате', 'ваше', 'ве', 'вазе', 'ваке', 'чаще', 'ваге', 'вале', 'варе', 'вате', 'ва', 'чаще', 'васе', 'ваше', 'ваге', 'васе', 'ваке', 'ване', 'ваке', 'вазе']
# []
# ['псе', 'фосен', 'фее', 'юсе', 'фосен', 'фсс', 'фея', 'исе', 'йсе', 'сие', 'уфе', 'е', 'фсб', 'нсе', 'офсет', 'лефсе', 'фус', 'эфесе', 'кфс', 'исе', 'ффе', 'фсу', 'фс8', 'ффе', 'фек', 'асе', 'сей', 'фее', 'сед', 'фер', 'све', 'офсет', 'фею', 'фсб', 'фск', 'сье', 'фюс', 'сео', 'сне', 'сле', 'сте', 'тсе', 'сле', 'нсе', 'фле', 'йсе', 'фрс', 'псе', 'феи', 'фсу', 'сев', 'асе', 'сое', 'тсе', 'ссе', 'сде', 'лефсе', 'все', 'сел', 'фсс', 'фре', 'рфс', 'сме', 'сем', 'все']
# ['обе', 'общее', 'общем', 'общ', 'общей', 'общие', 'вое', 'обе', 'обыще', 'овоще']
# ['милчу', 'смолу', 'имолу', 'молче', 'молче', 'олу', 'милчу', 'милчу', 'смолу', 'молчи', 'молча', 'моу', 'молчи', 'молча', 'мол']
# ['препараты', 'препараты', 'препараты']
# ['налет', 'надет', 'нет', 'намет', 'аще', 'надет', 'намет', 'нат', 'налет', 'аще', 'знает', 'налет']
# ['глиера', 'уивера', 'гулливер', 'глиера', 'уивера', 'гулливер']
# ['самши', 'осами', 'смыли', 'самых', 'усами', 'самуи', 'самым', 'саи', 'суами', 'самуи', 'самки', 'саамы', 'самсы', 'ами', 'салми', 'самцы', 'псами', 'саамы', 'самый', 'сарми', 'самым', 'ами', 'самши', 'самые', 'самир', 'саумы', 'сми', 'самые', 'самки', 'самых', 'сампи', 'самый', 'сампи', 'свами', 'самбы']
# ['своих', 'своей', 'своею', 'свели', 'своих', 'свопи', 'вое', 'своем', 'своде', 'своем', 'свопи', 'сви', 'свежи', 'свечи', 'своди', 'своем', 'солеи', 'усвое', 'своею', 'сои', 'своей', 'свети']
# ['гладкости', 'радости', 'гости', 'гости', 'радости', 'радости', 'гладкости']
# ['некк']
# ['обидети', 'одели', 'обители', 'обидети', 'обители', 'обидети', 'обители', 'одели']
# ['странным', 'странным', 'странным', 'страшным', 'страны']
# ['рекомендациях', 'рекомендациям', 'рекомендациям']
# []
# ['удалить', 'удалить', 'удалите', 'удалите', 'удалите']
# ['одноклассника', 'одноклассника']
# ['рэймон', 'ремонт', 'рэймон', 'эгмонт', 'эмон', 'ремонт', 'монт']
# []
# ['расин', 'раскинуто', 'траскин', 'расингу', 'расин', 'раскинуто', 'раскина', 'раскина']
# ['спул', 'плющ', 'сю', 'плюс', 'полю', 'палю', 'сю', 'селю', 'плющ', 'селю', 'спою', 'спал', 'салю', 'спил']
# []
# ['ване', 'вале', 'варище', 'варище', 'чаще', 'вате', 'ваше', 'ве', 'вазе', 'ваке', 'чаще', 'ваге', 'вале', 'варе', 'вате', 'ва', 'чаще', 'васе', 'ваше', 'ваге', 'васе', 'ваке', 'ване', 'ваке', 'вазе']
# ['снежка', 'снежинки', 'снежинки', 'снежинки', 'снежка', 'снежинок']
# ['шею', 'шез', 'шеа', 'ешьте', 'фее', 'шел', 'бешея', 'зее', 'тешев', 'еже', 'еде', 'нее', 'шек', 'хешен', 'еле', 'мешке', 'бетше', 'шеф', 'тешев', 'пешей', 'еже', 'егише', 'чешем', 'гешер', 'шуе', 'шие', 'еще', 'аше', 'еще', 'чеш', 'рее', 'еши', 'ешь', 'аше', 'керше', 'олеше', 'е', 'еес', 'йше', 'шее', 'щее', 'егише', 'еве', 'чешме', 'еле', 'шее', 'еве', 'йше', 'веш', 'мерше', 'шее', 'еде', 'хешен', 'оше', 'бешея', 'шее', 'нешер', 'ешь', 'мешех', 'пешек', 'олеше', 'мерше']
# ['застрелить', 'заселиться', 'застрелить', 'заселиться']
# []
# []
# ['прояснены', 'прояснены']
# ['каро', 'короче', 'калоче', 'карч', 'короче', 'карточек', 'кароем', 'карточке', 'карч', 'короче', 'карточек', 'калоче', 'карпое', 'калоче']
# ['температурах', 'температурам', 'температур', 'температурам']
# []
# ['качество', 'качество']
# ['ситкомы', 'симптом', 'итомы', 'ситкомы', 'симптом', 'симом']
# ['зачатия', 'зажатая', 'зажатая', 'нажатия', 'зачатия', 'зажатая', 'нажатия', 'нажатия', 'зачатия']
# ['пучковой', 'пупковской', 'пусковой', 'пучковой', 'пупковской', 'пусковой', 'пучковой']
# ['потам', 'порту', 'пту', 'потомуж', 'почту', 'апотому', 'порту', 'плоту', 'поэту', 'поэтому', 'отм', 'потомку', 'поэму', 'посту', 'пом', 'поэму', 'пойму', 'пойму']
# ['разе', 'разе']
# ['берущая', 'бегая', 'берущая', 'бегая', 'берущая']
# ['пришлось', 'пришлось', 'пришлось']
# ['каро', 'короче', 'калоче', 'карч', 'короче', 'карточек', 'кароем', 'карточке', 'карч', 'короче', 'карточек', 'калоче', 'карпое', 'калоче']
# []
# []
# []
# ['сосно', 'сосно']
# []
# ['посмотреть', 'посмотреть']
# []
# ['профессоре', 'профессору', 'профессоре', 'профессора']
# []
# []
# []
# ['небывало', 'небо', 'было', 'небо', 'было', 'небывало']
# ['жуков', 'мужиков', 'мужов', 'жуков', 'мужиков', 'мужиков']
# []
# ['поскольку', 'сколько', 'поскольку', 'поскольку', 'сколько']
# []
# ['компьютерные', 'компьютерные', 'компьютерные']
# ['начальное', 'начальные', 'начальное']
# ['подружился', 'ужился', 'подружился', 'дружил', 'ужился', 'дружил']
# ['начальнике', 'начальница', 'начальница', 'начальнике', 'начальнике', 'начальницу', 'начальница', 'начальницу']
# ['смотрим', 'смотрим']
# ['затеи', 'зарит', 'акити', 'таити', 'завитки', 'ати', 'зависти', 'знати', 'гаити', 'заи', 'ити', 'заи', 'таити', 'забит', 'апити', 'заики', 'зашит', 'защитим', 'завитки', 'гаити', 'зайти', 'защитив', 'защитил', 'защитив', 'зайти', 'заи']
# ['контакта', 'контакта', 'контакте', 'контракт', 'контакту', 'контакты']
# ['потеряна', 'потеряна', 'потеряна', 'потеряна']
# []
# []
# ['борть', 'борть', 'брать', 'уруть', 'убить', 'убирать', 'уруть', 'убить', 'брт']
# ['мишура', 'миру', 'мишура', 'мицуру', 'муру', 'ишкуру', 'ишкуру', 'муру', 'мицуру', 'мишура']
# ['процедура', 'процедура', 'процедура', 'процедура']
# ['коммунист', 'коммунист']
# []
# ['госдуму', 'гордому', 'гордому', 'госдуму', 'гордому', 'госдуму']
# ['беседня', 'беседня', 'сведя', 'ясеня', 'следя', 'средняя', 'сведя', 'седая', 'сегодня', 'средн', 'дня', 'сегодня', 'дня', 'сенья', 'седан', 'сенья', 'седан']
# []
# ['продавцу', 'продавцу', 'продавщица', 'продавщица', 'продавщица']
# ['ответственном', 'ответственном', 'ответственной', 'ответственное']
# []
# ['бесится', 'весит', 'бесту', 'бейси', 'беста', 'бесту', 'бески', 'берси', 'весит', 'брест', 'весит', 'бетси', 'бейси', 'бесси', 'бежит', 'бесится', 'бежит', 'бежит', 'бит']
# ['получатся', 'получатся']
# ['амона', 'монал', 'мощна', 'монжа', 'мовна', 'монна', 'можно', 'мощна', 'монка', 'мовна', 'монах', 'она', 'моржа', 'имона', 'можга', 'мовна', 'монца', 'омона', 'мжа', 'шмона', 'можам', 'монта', 'можно', 'можга', 'монса', 'мож', 'мон', 'монна']
# ['увольнять', 'увольняется', 'увольняется', 'увольнять']
# ['рисунок', 'рисунка', 'рисуной', 'рисунок', 'рисунке', 'рисунки', 'рисунке', 'рисунка', 'рисунку', 'рисунок', 'рисунку', 'рисунки', 'рисунку']
# ['мальчики', 'алчи', 'алик', 'малвик', 'мальчику', 'мальчики', 'мальчике', 'малика', 'малвик', 'алик']
# ['поение', 'пением', 'упрощением', 'поение', 'упрощением']
# ['суханова', 'сухова', 'суханова', 'суханова']
# ['мякость', 'мякость', 'яркость', 'мякость', 'кость']
# ['поти', 'потоку', 'потому', 'потому', 'потоки', 'потоси', 'потоки', 'потому']
# ['вызывают', 'взывал', 'взрывают', 'взрыва', 'взрыва', 'взывал']
# ['спасибо', 'спасибо', 'спасибо', 'спасибо']
# ['амона', 'монал', 'мощна', 'монжа', 'мовна', 'монна', 'можно', 'мощна', 'монка', 'мовна', 'монах', 'она', 'моржа', 'имона', 'можга', 'мовна', 'монца', 'омона', 'мжа', 'шмона', 'можам', 'монта', 'можно', 'можга', 'монса', 'мож', 'мон', 'монна']
# []
# []
# ['следуй', 'следуй', 'сведущий', 'сведущий', 'сведущий']
# ['основой', 'основны', 'основой', 'основны']
# ['сорочень', 'сорочень']
# ['обе', 'общее', 'общем', 'общ', 'общей', 'общие', 'вое', 'обе', 'обыще', 'овоще']
# ['псе', 'фосен', 'фее', 'юсе', 'фосен', 'фсс', 'фея', 'исе', 'йсе', 'сие', 'уфе', 'е', 'фсб', 'нсе', 'офсет', 'лефсе', 'фус', 'эфесе', 'кфс', 'исе', 'ффе', 'фсу', 'фс8', 'ффе', 'фек', 'асе', 'сей', 'фее', 'сед', 'фер', 'све', 'офсет', 'фею', 'фсб', 'фск', 'сье', 'фюс', 'сео', 'сне', 'сле', 'сте', 'тсе', 'сле', 'нсе', 'фле', 'йсе', 'фрс', 'псе', 'феи', 'фсу', 'сев', 'асе', 'сое', 'тсе', 'ссе', 'сде', 'лефсе', 'все', 'сел', 'фсс', 'фре', 'рфс', 'сме', 'сем', 'все']
# ['ошибочной', 'ошибочном', 'ошибочной', 'ошибочное']
# ['опаздывал', 'опаздывал', 'опаздывал']
# ['беседня', 'беседня', 'сведя', 'ясеня', 'следя', 'средняя', 'сведя', 'седая', 'сегодня', 'средн', 'дня', 'сегодня', 'дня', 'сенья', 'седан', 'сенья', 'седан']
# []
# []
# ['равняться', 'равняться']
# ['обозреватель', 'обогреватели', 'обозреватель', 'обозреватель', 'обогреватели', 'обогреватели']
# ['мокром', 'кроя', 'покроя', 'мокром', 'кроя', 'оком']
# ['канна', 'казнена', 'казнена']
# ['компания', 'компания', 'компания', 'компания']
# ['прекратит', 'превратят', 'превратил', 'превратится', 'превратив', 'превратят', 'превратится', 'превратил', 'прекратит', 'превратят', 'превратил', 'превратив', 'прекратит']
# ['фару', 'фары', 'марш', 'форш', 'кфар', 'фары', 'фарг', 'файр', 'фарм', 'сфар', 'форш', 'фш', 'фаркаш', 'фарг', 'фарп', 'фару', 'фарп', 'афар', 'фаши', 'харш', 'харш', 'фреш', 'фаркаш', 'фара', 'харш', 'фриш', 'марш', 'фарт', 'сфар', 'фарс', 'фарс', 'фш', 'фарт', 'фарм']
# []
# ['жеть', 'джут', 'жутань', 'муть', 'чуть', 'ть', 'жуёт', 'джут', 'усть', 'путь', 'жути', 'жути', 'чуть', 'ждут', 'путь', 'жутань', 'ть', 'жу', 'муть', 'суть', 'суть', 'жеть', 'жить', 'жить', 'жгут']
# []
# ['нахожусь', 'нахожусь']
# ['непонятное', 'непонятное', 'непонятным', 'непонятным', 'непонятным', 'непонятное']
# []
# ['следующей', 'следующей', 'следующей']
# ['залипания', 'залипания', 'залипания']
# []
# ['саласу', 'жайлау', 'слау', 'сайа', 'айла', 'айла', 'саласу', 'скайла', 'жайлау', 'салаку']
# []
# ['ване', 'вале', 'варище', 'варище', 'чаще', 'вате', 'ваше', 'ве', 'вазе', 'ваке', 'чаще', 'ваге', 'вале', 'варе', 'вате', 'ва', 'чаще', 'васе', 'ваше', 'ваге', 'васе', 'ваке', 'ване', 'ваке', 'вазе']
# []
# ['организмы', 'организмы', 'организмы', 'организмы']
# ['браться', 'браться']
# []
# ['обычно', 'обучен', 'очно', 'очно', 'обычно', 'обучен', 'учно']
# ['долго']
# ['алупы', 'алупы', 'залпе', 'залпе', 'залпа', 'злы', 'залпа', 'залпа', 'зап', 'залын', 'альпы', 'злы']
# ['беглянку', 'беглянку']
# ['серебряно', 'серебряному', 'серебряно']
# ['периодически', 'периодически', 'периодически']
# ['беседня', 'беседня', 'сведя', 'ясеня', 'следя', 'средняя', 'сведя', 'седая', 'сегодня', 'средн', 'дня', 'сегодня', 'дня', 'сенья', 'седан', 'сенья', 'седан']
# ['календари', 'календари']
# []
# []
# ['любому', 'любому']
# ['шею', 'шез', 'шеа', 'ешьте', 'фее', 'шел', 'бешея', 'зее', 'тешев', 'еже', 'еде', 'нее', 'шек', 'хешен', 'еле', 'мешке', 'бетше', 'шеф', 'тешев', 'пешей', 'еже', 'егише', 'чешем', 'гешер', 'шуе', 'шие', 'еще', 'аше', 'еще', 'чеш', 'рее', 'еши', 'ешь', 'аше', 'керше', 'олеше', 'е', 'еес', 'йше', 'шее', 'щее', 'егише', 'еве', 'чешме', 'еле', 'шее', 'еве', 'йше', 'веш', 'мерше', 'шее', 'еде', 'хешен', 'оше', 'бешея', 'шее', 'нешер', 'ешь', 'мешех', 'пешек', 'олеше', 'мерше']
# ['реклам', 'реклам', 'рема', 'река', 'река', 'реклам']
# ['обслуживанием', 'обслуживанием']
# ['безупречно', 'безупречно']
# ['ранам', 'арена', 'алена', 'ирана', 'авена', 'графена', 'раменка', 'ревна', 'ранен', 'райна', 'крана', 'мрена', 'брайена', 'ана', 'юрана', 'рагна', 'рагна', 'трена', 'ранен', 'ренна', 'урана', 'орана', 'ранца', 'раина', 'ахена', 'ана', 'ррена', 'ренат', 'рента', 'ревна', 'ранга', 'ранах', 'руана', 'размена', 'размена', 'райна', 'раина', 'хрена', 'дрена', 'реа', 'ранда', 'графена', 'ррена', 'ранса', 'ренан', 'френа']
# ['объясняли', 'объяснила', 'объяснили', 'объяснить', 'объяснить', 'объясняли', 'объяснило', 'объяснила']
# ['сначала', 'началом', 'скачало', 'началом', 'сначала', 'скачало', 'сначала', 'скачало']
# ['продолжительность', 'продолжительность', 'продолжительность']
# ['нельша', 'нельша']
# []
# []
# ['симпатичный', 'симпатичный', 'симпатичный']
# ['всякой', 'всякий', 'всякой', 'всякий', 'всяк', 'всяк']
# ['прокул', 'породу', 'продал', 'прокул', 'роду', 'прокул', 'роду', 'продал', 'продал', 'поул']
# ['вольно', 'довольно', 'довольно', 'довольно']
# []
# ['открылы', 'открыло', 'открыли', 'открыла', 'открыли']
# []
# ['поддельная', 'поддельная', 'подделан', 'подделан', 'поддельная']
# []
# ['подробны', 'подобный', 'подобный', 'подобный']
# []
# ['постигли', 'постиг', 'постигли']
# ['вечном', 'верхом', 'ветром', 'ветром', 'вечном', 'веером', 'веро', 'верном', 'веером', 'верном']
# ['вкусом', 'вкусно', 'вкусно']
# ['отечественные', 'отечественные', 'отечественные', 'отечественные']
# ['пряно', 'пряно', 'приятно', 'приятно', 'пятно']
# []
# []
# ['кстати', 'костанте', 'статен', 'кате', 'сате', 'статей', 'костанте', 'сате', 'кстати', 'статье', 'кстати', 'старте', 'статуе', 'стае']
# ['шульца', 'льга', 'шульца', 'шульца', 'шульги', 'шульги', 'шульгина', 'шульги', 'льга']
# ['зириным', 'зириным', 'зиминым']
# ['знаю', 'знаю', 'незнанию', 'незнанию']
# ['смотрелся', 'смотрелся']
# ['периодически', 'периодически', 'периодически']
# ['лося', 'лора', 'лора', 'лося']
# ['обе', 'общее', 'общем', 'общ', 'общей', 'общие', 'вое', 'обе', 'обыще', 'овоще']
# ['сарду', 'сряду', 'броду', 'сряду', 'проду', 'ироду', 'сходу', 'среду', 'сроку', 'сро', 'содду', 'сходу', 'староду', 'среду', 'своду', 'броду', 'проду', 'сходу', 'проду', 'сряду', 'сроку', 'родоу', 'своду', 'ироду', 'сро']
# []
# ['выходу', 'выходу', 'вхож', 'выходу', 'вхож']
# ['решающем', 'решаемой', 'решающем', 'решаемой', 'решаемым', 'решаемых', 'решает', 'реем', 'реша', 'реша', 'решает', 'реем', 'решаемым', 'решаемых']
# []
# ['оный', 'горным', 'оныя', 'ложным', 'оныя', 'ложным', 'фоны', 'оные', 'модным', 'олым', 'полным', 'онмк', 'оном', 'осны', 'фоны', 'оных', 'юным', 'ым', 'роны', 'водным', 'конным', 'ровным', 'онмк', 'точным', 'точным', 'зоны', 'модным', 'охнм', 'горным', 'ым', 'иным', 'оный', 'нотным', 'боны', 'юным', 'оные', 'оных', 'конным', 'олым', 'нотным', 'мощным', 'донным', 'ионы', 'соны', 'оном']
# []
# ['коньяк', 'коньяк']
# ['келой', 'корелой', 'колол', 'голой', 'колоб', 'колов', 'лой', 'колом', 'корой', 'полой', 'колон', 'колом', 'долой', 'косой', 'колол', 'кобой', 'колотой', 'кой', 'колоб', 'колон', 'голой', 'колотой', 'корелой', 'колоний', 'около', 'кодой', 'колов', 'лолой', 'колей', 'косой', 'лолой', 'колос', 'козло', 'полой', 'колодий', 'кой', 'долой', 'колос', 'кодой', 'николой', 'кобой', 'колоний', 'николой', 'колотой', 'лой', 'колей']
# ['спрашивал', 'спрашивал', 'спрашивал', 'спрашивая', 'спрашивая']
# ['чью', 'чта', 'тья', 'чти', 'чтить', 'сть', 'честь', 'чье', 'что', 'учить', 'ять', 'часть', 'сть', 'ять', 'чта', 'чутьё', 'чёт', 'честь', 'чти', 'чутьё', 'ч', 'чти', 'что', 'чтить']
# ['естественной', 'естественной', 'естественном', 'естественное']
# ['естественной', 'естественной', 'естественном', 'естественное']
# ['повете', 'повете']
# ['пили', 'приз', 'лизи', 'пи', 'лизе', 'близ', 'плит', 'пали', 'плит', 'пизы', 'лизу', 'пи', 'пули', 'линз', 'пели', 'элиз', 'приз', 'лиаз', 'луиз', 'близ', 'пиза', 'элиз', 'пыли', 'пл', 'поли', 'элиз']
# ['обычными', 'обычны', 'побочным', 'побочным', 'ночным', 'точным', 'точным', 'сочным', 'обычными', 'оброчным']
# ['так']
# ['уши', 'сушат', 'сшить', 'сшиты', 'суита', 'сушки', 'суифт', 'уши', 'сут', 'сшить', 'душит', 'суифт', 'душит', 'сушат']
# ['естественной', 'естественной', 'естественном', 'естественное']
# ['протянулись', 'протянулись', 'протянулись']
# ['естественной', 'естественной', 'естественном', 'естественное']
# ['загибается', 'загибается', 'загибается']
# ['спасибов', 'спасибов']
# ['начальное', 'начальные', 'начальное']
# ['подымать', 'подать', 'подумать', 'понимать', 'понимать', 'подать', 'подумать', 'подымать']
# []
# ['предположительное', 'предположительной', 'предположительной']
# ['неожиданный', 'неожиданный', 'неожиданный']
# ['мальче', 'мальче']
# ['хорошее', 'хорее', 'хорее', 'хорошее', 'хорошее']
# ['потому', 'потоку', 'потому', 'потому', 'помогу', 'потому', 'помогу']
# ['работодатели', 'работодатели', 'работодатели']
# []
# ['негодовании', 'негодование', 'негодований', 'негодования', 'негодование', 'негодований', 'негодования', 'негодование', 'негодовании']
# ['гео', 'тот', 'зто', 'тою', 'рто', 'тто', 'удето', 'тох', 'тетко', 'топ', 'четой', 'тоф', 'петио', 'бто', 'метро', 'етр', 'летов', 'тпо', 'тпо', 'ивето', 'ото', 'нто', 'тод', 'веток', 'тто', 'тао', 'метро', 'тбо', 'летов', 'летно', 'фетой', 'тво', 'ато', 'рто', 'ньето', 'кто', 'ито', 'нео', 'мто', 'жетон', 'уто', 'шесто', 'ево', 'е', 'тоу', 'тож', 'что', 'веток', 'удето', 'е', 'тое', 'гто', 'тоя', 'тхо', 'жетон', 'точ', 'зто', 'кетоз', 'это', 'том', 'той', 'его', 'ело', 'хто', 'это', 'беато', 'тол', 'тоо', 'пто', 'хто', 'тео', 'шесто', 'што', 'пет', 'ета', 'тюо', 'йео', 'тэо', 'ото', 'кетоз', 'цвето', 'сетон', 'беато', 'желто']
# []
# ['вчерашний', 'вчерашний', 'вчерашние', 'вчерашний', 'вчерашние']
# ['беседня', 'беседня', 'сведя', 'ясеня', 'следя', 'средняя', 'сведя', 'седая', 'сегодня', 'средн', 'дня', 'сегодня', 'дня', 'сенья', 'седан', 'сенья', 'седан']
# []
# ['пользователь', 'пользоваться', 'использовать', 'пользователь', 'использовать', 'пользоваться']
# ['очное', 'очень', 'очное', 'оне', 'очные', 'очень', 'очень', 'очень']
# ['куала', 'скучали', 'скучали', 'скала', 'скала', 'скучали']
# ['кстати', 'костанте', 'статен', 'кате', 'сате', 'статей', 'костанте', 'сате', 'кстати', 'статье', 'кстати', 'старте', 'статуе', 'стае']
# ['дева', 'девушкам', 'евка', 'дека', 'древка', 'девушкам', 'древка']
# ['21617']
# ['объяснит', 'объяснит', 'пояснить', 'пояснить']
# []
# ['двухполосная', 'двухполосная', 'двухполосная']
# ['придела', 'приезжала', 'приезжала', 'приза', 'прицела', 'привела', 'приезда', 'приезда', 'приезда', 'привела']
# ['чудища', 'чуди', 'будище', 'чудовище', 'будище', 'чудища', 'чудища', 'чище', 'чуде', 'чище', 'будище', 'чудовище']
# []
# ['обернуться', 'обернуться']
# ['некоторм', 'некоторыми', 'некоторм']
# ['паря', 'упрямо', 'прямой', 'поря', 'прямых', 'прямым', 'поря', 'впрямь', 'пром', 'ям', 'пром', 'впрямь', 'перя', 'хрям', 'прямые', 'прямая', 'хрям', 'пром', 'прямая', 'прая', 'прим', 'прямой', 'прам', 'прямым', 'ям', 'прямую', 'прим', 'парням', 'прямым', 'прямую']
# ['монсеррато', 'монтсеррат', 'монсеррато']
# ['следуй', 'следуй', 'сведущий', 'сведущий', 'сведущий']
# ['13015']
# ['матери', 'матвею', 'матвею', 'матери', 'матерь', 'мастер', 'матфею', 'мате', 'матерь']
# ['беседня', 'беседня', 'сведя', 'ясеня', 'следя', 'средняя', 'сведя', 'седая', 'сегодня', 'средн', 'дня', 'сегодня', 'дня', 'сенья', 'седан', 'сенья', 'седан']
# ['леший', 'решил', 'лечил', 'решил', 'лешие', 'улеши', 'олеши', 'лечил', 'лишил', 'бешил', 'лил', 'лечил', 'олеши', 'леший', 'решил', 'лешие', 'бешил', 'лишил']
# []
# ['касем', 'касемом', 'касемом']
# ['пройдя', 'пройдя', 'пройдя']
# ['эрени', 'ренди', 'эрени']
# []
# ['извините', 'извините', 'зените', 'ивенте', 'зените', 'извините', 'звенит', 'ивенте']
# []
# ['норштейна', 'норштейна']
# ['покорилась', 'покорилась', 'покорилась']
# []
# []
# []
# ['лыжу', 'ёж', 'лц', 'жд', 'гл', 'дл', 'лё', 'ль', 'сж', 'ол', 'ул', 'тл', 'лэ', 'лодж', 'лю', 'ля', 'лужа', 'ланж', 'бл', 'ль', 'лл', 'йл', 'жо', 'лб', 'жм', 'лы', 'ложи', 'клуж', 'лп', 'фл', 'рж', 'жэ', 'рж', 'лр', 'жж', 'лыжу', 'лжец', 'ял', 'лм', 'лк', 'сж', 'лп', 'мл', 'иж', 'лю', 'жк', 'цл', 'ле', 'еж', 'чл', 'иж', 'еж', 'тж', 'лл', 'лё', 'жж', 'аж', 'эл', 'лб', 'лё', 'вл', 'пл', 'жи', 'лв', 'лв', 'ля', 'аж', 'еж', 'лужа']
# ['ложу', 'вылову', 'вылову', 'вылову', 'ложу']
# ['начала', 'нача', 'сала', 'сала', 'нача']
# ['пластыря', 'пласты', 'пластыря', 'латырь', 'пластыря', 'латырь']
# []
# ['рюкзака', 'рюкзака']
# ['ночную', 'нону', 'оную', 'ноту', 'нону', 'ночную']
# ['милчу', 'смолу', 'имолу', 'молче', 'молче', 'олу', 'милчу', 'милчу', 'смолу', 'молчи', 'молча', 'моу', 'молчи', 'молча', 'мол']
# ['ване', 'вале', 'варище', 'варище', 'чаще', 'вате', 'ваше', 'ве', 'вазе', 'ваке', 'чаще', 'ваге', 'вале', 'варе', 'вате', 'ва', 'чаще', 'васе', 'ваше', 'ваге', 'васе', 'ваке', 'ване', 'ваке', 'вазе']
# ['официальное', 'официальное', 'официальное']
# ['можайка', 'мойка', 'зайка', 'майка', 'мозаика', 'можайка', 'мойка', 'мозаика', 'мозаика']
# ['любо', 'любеке', 'любеке']
# []
# []
# ['истор', 'истор', 'история', 'история', 'история']
# []
# []
# ['погрузился', 'погрузился']
# []
# ['набрал', 'набирала', 'набирала', 'набрал']
# []
# []
# ['аккорд', 'аккорд']
# ['брэдом', 'бандом', 'бандом', 'бэно', 'бэнд', 'бэндов', 'бандом', 'эдом', 'бэндов', 'бондом', 'брэдом', 'бэно', 'бондом']
# []
# []
# []
# ['неоднозначное', 'неоднозначное', 'неоднозначное']
# ['внутренний', 'внутренний', 'внутренний']
# ['торопятся', 'торопятся']
# ['нагано', 'наглядно', 'нагано', 'наглядно', 'наглядно']
# ['приво', 'приво', 'приводу', 'приводу']
# ['расчете', 'рассвет', 'расчете', 'рассвет', 'рассвет', 'расчеты', 'расчету', 'расчета']
# ['поэтому', 'полетом', 'почетом', 'пометом', 'апотому', 'поэтому', 'потомку', 'поэтому', 'одетому', 'потомуж', 'одетому', 'пометом']
# []
# ['эмоциональная', 'эмоциональная', 'эмоциональная', 'эмоциональная']
# []
# []
# ['уде', 'будет', 'будде', 'беш', 'будет', 'беш', 'будем', 'будке', 'обуде', 'буш', 'уде', 'будье', 'бунде', 'блуде', 'будем']
# ['махине', 'махине', 'мане', 'марине', 'марине', 'машине', 'махине', 'машине', 'мине']
# ['обе', 'общее', 'общем', 'общ', 'общей', 'общие', 'вое', 'обе', 'обыще', 'овоще']
# ['естественной', 'естественной', 'естественном', 'естественное']
# []
# []
# ['долго']
# ['тянули', 'тянулась', 'янаула', 'тула', 'затянула', 'тянуло', 'янаула', 'тула', 'дотянула', 'тянуло', 'дотянула', 'тянуло', 'тянули', 'затянула', 'тянулась', 'стянул']
# []
# ['пятиэтажке', 'пятиэтажке', 'пятиэтажек', 'пятиэтажке']
# ['благодаря', 'благодаря', 'благодаря']
# ['вольно', 'довольно', 'довольно', 'довольно']
# ['привык', 'привыкли', 'привычка', 'привыкли', 'привыкая', 'привык']
# ['имени', 'имени', 'именным', 'именным', 'именицы', 'именные', 'именных', 'имениты', 'имениты', 'именицы']
# []
# ['преодолением', 'преодолением']
# []
# ['поползли', 'поли', 'олли', 'поползли', 'поли', 'олли', 'поползли', 'поползли']
# ['приспособление', 'приспособление', 'приспособление']
# []
# []
# []
# ['беседня', 'беседня', 'сведя', 'ясеня', 'следя', 'средняя', 'сведя', 'седая', 'сегодня', 'средн', 'дня', 'сегодня', 'дня', 'сенья', 'седан', 'сенья', 'седан']
# []
# []
# ['божию', 'бомжихи', 'оми', 'оми', 'бомжихи', 'божие', 'божеи', 'бомин', 'божие', 'божич', 'боями', 'божьи', 'бом', 'бомжихи', 'божий', 'божия']
# ['дерущийся', 'дерущийся', 'дерущийся', 'дерущихся', 'дерущихся']
# ['божию', 'бомжихи', 'оми', 'оми', 'бомжихи', 'божие', 'божеи', 'бомин', 'божие', 'божич', 'боями', 'божьи', 'бом', 'бомжихи', 'божий', 'божия']
# ['осталось', 'оставалось', 'осталось', 'осталась', 'осталось', 'осталось', 'оставалось']
# []
# ['вида', 'вида']
# ['страус', 'статус', 'страты', 'статус', 'страты']
# ['смешны', 'смешны', 'сные', 'сные']
# []
# ['арске', 'маске', 'ась', 'асаке', 'васке', 'даске', 'ась', 'аскер', 'сье', 'гаске', 'асаке', 'даске', 'аскет']
# []
# []
# ['джинсов', 'джинсов']
# ['естественной', 'естественной', 'естественном', 'естественное']
# ['сжалились', 'сжалились', 'влились', 'сжалились', 'свалилась', 'свалилась', 'свалили', 'свалилось', 'свалили', 'свалилось', 'свалилась', 'слились']
# ['моку', 'моук', 'миоз', 'мока', 'моск', 'мозаик', 'оз', 'мсок', 'озек', 'мк', 'моздок', 'моск', 'монк', 'мозаик', 'мрзк', 'моздок', 'моск', 'мрзк', 'мойз', 'мохк', 'мохк', 'мозг', 'моко', 'оз', 'моке', 'ямок', 'моук', 'мозг', 'моез', 'монк']
# ['треснуто', 'треснуто', 'треснуто']
# ['сначала', 'началом', 'скачало', 'началом', 'сначала', 'скачало', 'сначала', 'скачало']
# ['тарасу', 'таурус', 'тарасу', 'таруса', 'русу', 'тарусе', 'тарусе', 'парусу', 'таус', 'таруса', 'русу', 'парусу', 'тару', 'тартус', 'тарасу', 'таурус']
# ['тесно', 'сосно', 'сосно', 'лесно', 'тесно', 'бессо', 'бессо', 'есн']
# ['зерцала', 'зерцала']
# ['заффт', 'заффт']
# ['попробуй', 'попробуй', 'попробуй']
# ['совершенной', 'совершенном', 'совершенное', 'совершенной', 'совершено']
# []
# ['озноб', 'озноб']
# ['зарывалась', 'зарывалась']
# ['кстати', 'костанте', 'статен', 'кате', 'сате', 'статей', 'костанте', 'сате', 'кстати', 'статье', 'кстати', 'старте', 'статуе', 'стае']
# ['получатся', 'получатся']
# ['неделимой', 'неделимые', 'неделимые', 'неделимой', 'неделимые', 'неделимой']
# ['маршрутка', 'машутки', 'маршруток', 'маршрут', 'маршрутка', 'машутки', 'маршрут']
# ['битном', 'убитом', 'ситком', 'ситком', 'битном', 'бико', 'обитом', 'щитком', 'ситком', 'биом', 'щитком', 'битником', 'биом']
# ['придается', 'придается']
# []
# []
# []
# ['горбатюк', 'горбатюк']
# []
# ['наконец', 'наконец']
# ['ученики', 'ручки', 'ученики', 'ручек', 'ручек']
# ['кнопки', 'кнопки']
# []
# ['наказать', 'наказать', 'наказать']
# ['случалось', 'случалось']
# ['прикладывая', 'прикладывая', 'прикладывая']
# ['логику', 'лику', 'лорику', 'лоби', 'облику', 'облику', 'лорику', 'лорику', 'логику', 'лоби']
# ['извлеченные', 'изувеченное', 'извлечено', 'извлечено', 'изувеченное', 'извлеченные', 'извлеченные']
# ['осматривает', 'осматривает', 'осматривает']
# ['следит', 'следит']
# ['пассажира', 'пассажирами', 'пассажирами']
# ['жаки', 'лежа', 'лежаками', 'слежки', 'лежали', 'жаки', 'леки', 'лежаками', 'леки', 'лежали', 'лежали']
# ['территорию', 'территорию', 'территорию', 'территорию']
# ['любопытства', 'любопытства', 'любопытства']
# []
# []
# ['налет', 'надет', 'нет', 'намет', 'аще', 'надет', 'намет', 'нат', 'налет', 'аще', 'знает', 'налет']
# ['родные', 'народные', 'народные', 'однородные', 'родные', 'однородные']
# ['обливание', 'отбеливания', 'отбеливания', 'отбеливания', 'обливание']
# ['шею', 'шез', 'шеа', 'ешьте', 'фее', 'шел', 'бешея', 'зее', 'тешев', 'еже', 'еде', 'нее', 'шек', 'хешен', 'еле', 'мешке', 'бетше', 'шеф', 'тешев', 'пешей', 'еже', 'егише', 'чешем', 'гешер', 'шуе', 'шие', 'еще', 'аше', 'еще', 'чеш', 'рее', 'еши', 'ешь', 'аше', 'керше', 'олеше', 'е', 'еес', 'йше', 'шее', 'щее', 'егише', 'еве', 'чешме', 'еле', 'шее', 'еве', 'йше', 'веш', 'мерше', 'шее', 'еде', 'хешен', 'оше', 'бешея', 'шее', 'нешер', 'ешь', 'мешех', 'пешек', 'олеше', 'мерше']
# ['часовой']
# ['кодексах', 'кодексом', 'кодексом', 'кодексом', 'кодекс', 'кодеками', 'кодексах', 'кодеками']
# ['заверил', 'заверил', 'звери', 'звери']
# []
# ['подставив', 'приставив', 'подставив', 'простив', 'приставив', 'приставив', 'предоставив', 'предоставив', 'простив', 'оставив']
# ['официальино', 'официальное', 'официальном', 'официальной', 'официальной']
# ['поздравлял', 'поздравлял', 'поздравлял']
# ['хорошему', 'хороша', 'дороше', 'хоре', 'хороле', 'хорошего', 'хорошеву', 'хорошо', 'хоре', 'хорошеву', 'хороша', 'хороша', 'хороши', 'хороши', 'хороле', 'роше', 'роше', 'хорошо', 'дороше']
# ['образовались', 'радовались', 'образовались', 'образовались', 'радовались']
# ['доброжелательные', 'доброжелательные', 'доброжелательным', 'доброжелательным', 'доброжелательных', 'доброжелательным', 'доброжелательных']
# ['очень']
# ['наказанными', 'наказанными', 'наказанными']
# []
# []
# ['обе', 'общее', 'общем', 'общ', 'общей', 'общие', 'вое', 'обе', 'обыще', 'овоще']
# []
# ['соедините', 'соедините', 'соедините']
# ['вообще', 'общему', 'всеобщем', 'всеобщем', 'общему', 'обще']
# []
# ['практический', 'практический', 'практическим', 'практических', 'практические']
# []
# []
# ['естественной', 'естественной', 'естественном', 'естественное']
# ['свола', 'свола']
# ['подходу', 'подходу', 'подходу', 'похож', 'похож', 'похожую']
# []
# ['аят', 'опять', 'пятью', 'опять', 'ять', 'лаять', 'таять', 'ять']
# ['сводня', 'сводня', 'годная', 'годная', 'сводня', 'соня']
# ['стрельбищем', 'стрельбищем']
# ['канто', 'кокто', 'актов', 'каско', 'катод', 'какой', 'факто', 'лакто', 'аркто', 'кайко', 'факто', 'какое', 'какао', 'какао', 'карто', 'катон', 'окато', 'канто', 'окато', 'какой', 'каток', 'каком', 'акт', 'кто', 'кокто', 'лакто', 'акт']
# []
# ['кулера', 'куре', 'купере', 'клее', 'улер', 'кулеры', 'улер', 'куре', 'куле', 'кулеры', 'кулера', 'купере']
# ['смешиванию', 'смешиванию']
# []
# ['холодная']
# []
# ['ване', 'вале', 'варище', 'варище', 'чаще', 'вате', 'ваше', 'ве', 'вазе', 'ваке', 'чаще', 'ваге', 'вале', 'варе', 'вате', 'ва', 'чаще', 'васе', 'ваше', 'ваге', 'васе', 'ваке', 'ване', 'ваке', 'вазе']
# []
# []
# ['элитно', 'элитно']
# []
# ['налет', 'надет', 'нет', 'намет', 'аще', 'надет', 'намет', 'нат', 'налет', 'аще', 'знает', 'налет']
# []
# ['тесно', 'сосно', 'сосно', 'лесно', 'тесно', 'бессо', 'бессо', 'есн']
# ['экскурсовод', 'экскурсовод']
# ['зачете', 'насчет', 'узнает', 'означает', 'начнет', 'значит', 'начнет', 'зачета', 'значит', 'узнает', 'значат', 'значат', 'зачета', 'значат', 'значке', 'значке']
# ['субботу', 'субботу']
# ['окажут', 'окажут', 'покажу']
# ['кедах', 'ведал', 'медал', 'кедра', 'дедал', 'кендалл', 'кал', 'кедар', 'медал', 'кведа', 'кендалл', 'есдал', 'дал', 'кендала', 'ведал', 'скеда', 'есдал', 'кедар', 'кедах', 'дедал']
# ['кеды', 'кеды']
# []
# []
# []
# ['предлагают', 'предлагают']
# ['равняться', 'равняться']
# ['покачаться', 'показаться', 'показаться', 'покачаться', 'показаться']
# ['вы', 'выти', 'выти', 'вехи', 'выходи', 'всхи', 'вяхи', 'вехи', 'выходи', 'ых', 'вы', 'всхи', 'выми', 'вяхи', 'вяхи', 'выхино', 'выми', 'выхино']
# ['сюда', 'алда', 'блюдах', 'люта', 'ляда', 'людо', 'блюдау', 'люфа', 'блюдах', 'рюда', 'льда', 'рюда', 'леда', 'люга', 'лада', 'сюда', 'люба', 'олда', 'леда', 'люде', 'лода', 'люна', 'люна', 'людо', 'люка', 'лида', 'лода', 'люде', 'луда', 'люде', 'люба', 'слюдам', 'люди', 'ляда', 'люта', 'лида', 'сюда', 'луда', 'люфа', 'люди', 'лада', 'льда', 'улда', 'люка', 'люга', 'люта', 'льда']
# ['очень']
# []
# ['елью', 'мелю', 'целы', 'цилю', 'ценю', 'цела', 'цели', 'челю', 'челю', 'ценю', 'ценю', 'лю', 'целы', 'велю', 'мелю', 'целы', 'цели', 'цилю', 'челю', 'ацел', 'селю', 'велю', 'цель', 'цела', 'селю']
# []
# []
# ['моторно', 'мутоном', 'мутно', 'мутоном', 'моторно', 'моторно']
# ['общем', 'общем']
# []
# ['аптекарской', 'пекарский', 'пекарский', 'аптекарской', 'карской', 'карской', 'пекарский']
# []
# ['бедру', 'бедру', 'кедру', 'педру', 'цедры', 'цер', 'еду', 'цру', 'педру', 'цедры', 'цер', 'бедру', 'кедру']
# ['суть', 'сузить', 'суши', 'суши', 'рушить', 'сузить', 'судить', 'душить', 'судить', 'тушить', 'сузить', 'шить', 'рушить', 'тушить', 'тушить', 'душить']
# ['кстати', 'костанте', 'статен', 'кате', 'сате', 'статей', 'костанте', 'сате', 'кстати', 'статье', 'кстати', 'старте', 'статуе', 'стае']
# []
# []
# ['собственно', 'собственно', 'собственно']
# ['одноклассники', 'одноклассники', 'одноклассники']
# []
# ['соратником', 'соратником', 'соратник', 'соратник']
# ['дирижабли', 'дирижабля', 'дирижабли']
# ['обжа', 'обожаю', 'обнажают', 'обожаю', 'обнажают', 'обожаю']
# []
# []
# ['небывало', 'небо', 'было', 'небо', 'было', 'небывало']
# ['созерцать', 'созерцать', 'созерцать']
# ['хорошему', 'хороша', 'дороше', 'хоре', 'хороле', 'хорошего', 'хорошеву', 'хорошо', 'хоре', 'хорошеву', 'хороша', 'хороша', 'хороши', 'хороши', 'хороле', 'роше', 'роше', 'хорошо', 'дороше']
# ['провинция', 'провинция', 'провинция', 'провинция']
# ['скульптурах', 'скульптурам', 'скульптур', 'скульптур']
# ['разгадать', 'разгадать', 'раздать', 'раздать']
# []
# ['тото']
# ['ночь', 'точь', 'мч', 'мелочь', 'мочу', 'моча', 'точь', 'точь', 'дочь', 'мочить', 'мочи', 'мечь', 'моча', 'моль', 'моль', 'мелочь', 'мощь', 'мочить', 'мочу', 'моль', 'дочь', 'моче', 'моче', 'помочь', 'помочь', 'мощь', 'ночь', 'мочу']
# ['обязательно', 'обязательно', 'обязательно']
# ['сделать', 'сделать', 'сделать']
# ['настоящий', 'настоящий', 'настоящий']
# ['гео', 'тот', 'зто', 'тою', 'рто', 'тто', 'удето', 'тох', 'тетко', 'топ', 'четой', 'тоф', 'петио', 'бто', 'метро', 'етр', 'летов', 'тпо', 'тпо', 'ивето', 'ото', 'нто', 'тод', 'веток', 'тто', 'тао', 'метро', 'тбо', 'летов', 'летно', 'фетой', 'тво', 'ато', 'рто', 'ньето', 'кто', 'ито', 'нео', 'мто', 'жетон', 'уто', 'шесто', 'ево', 'е', 'тоу', 'тож', 'что', 'веток', 'удето', 'е', 'тое', 'гто', 'тоя', 'тхо', 'жетон', 'точ', 'зто', 'кетоз', 'это', 'том', 'той', 'его', 'ело', 'хто', 'это', 'беато', 'тол', 'тоо', 'пто', 'хто', 'тео', 'шесто', 'што', 'пет', 'ета', 'тюо', 'йео', 'тэо', 'ото', 'кетоз', 'цвето', 'сетон', 'беато', 'желто']
# ['вашей', 'вещей', 'пешей', 'вещей', 'пешей', 'внешней', 'веш', 'велей', 'внесшей', 'вашей', 'кешей', 'велей', 'уведшей', 'вашей', 'швеей', 'велей', 'вышей', 'пешей', 'веш', 'кешей', 'вышей', 'внешней', 'уведшей']
# ['оша', 'общая', 'оба', 'общая', 'общая', 'бая']
# []
# ['мацки', 'цки', 'аци', 'цки', 'дацки']
# ['кощунство', 'кощунство', 'кощунство']
# ['способностью', 'способностью']
# []
# ['территориия', 'территориям', 'территориях', 'территориия']
# ['одноклассники', 'одноклассники', 'одноклассники']
# []
# ['голосов', 'горов', 'осв', 'госва', 'голов', 'носов', 'носов', 'годов', 'носов', 'голосов', 'голов', 'осо', 'оксов', 'голосов', 'овсов', 'основ', 'остов', 'гсв', 'горов', 'годов', 'готов', 'госпо']
# ['здесь', 'здесь', 'сде', 'здесь', 'спесь', 'сесть', 'смесь', 'смесь', 'сесть', 'днесь', 'сде', 'спесь']
# ['развиться', 'направиться', 'направиться', 'развиться', 'понравиться', 'понравиться']
# ['сложен', 'осложнён', 'сложен', 'осложнение', 'осложнений', 'осложнение', 'осложнён', 'осложнён', 'осложнения']
# ['программа', 'программа', 'программа']
# []
# ['подорванная', 'подорванная']
# ['извините', 'извините', 'зените', 'ивенте', 'зените', 'извините', 'звенит', 'ивенте']
# ['выродился', 'выродился', 'вывозился', 'выразился', 'выразился', 'вывозился', 'вывозился', 'выразился', 'выродился']
# ['напомнил', 'напомнил']
# ['старый']
# ['пройдя', 'прийде', 'пройдя', 'прий', 'пройдя', 'прийде', 'прий']
# ['ирокез', 'ирокез', 'ирокез', 'сираке', 'сираке', 'раке', 'ирак', 'шираке']
# ['гео', 'тот', 'зто', 'тою', 'рто', 'тто', 'удето', 'тох', 'тетко', 'топ', 'четой', 'тоф', 'петио', 'бто', 'метро', 'етр', 'летов', 'тпо', 'тпо', 'ивето', 'ото', 'нто', 'тод', 'веток', 'тто', 'тао', 'метро', 'тбо', 'летов', 'летно', 'фетой', 'тво', 'ато', 'рто', 'ньето', 'кто', 'ито', 'нео', 'мто', 'жетон', 'уто', 'шесто', 'ево', 'е', 'тоу', 'тож', 'что', 'веток', 'удето', 'е', 'тое', 'гто', 'тоя', 'тхо', 'жетон', 'точ', 'зто', 'кетоз', 'это', 'том', 'той', 'его', 'ело', 'хто', 'это', 'беато', 'тол', 'тоо', 'пто', 'хто', 'тео', 'шесто', 'што', 'пет', 'ета', 'тюо', 'йео', 'тэо', 'ото', 'кетоз', 'цвето', 'сетон', 'беато', 'желто']
# ['прикол', 'прокол', 'прокол', 'прикол', 'прокол']
# []
# ['двери']
# ['ехал', 'выехал', 'выехал', 'выехал', 'въехал', 'въехал']
# ['асаново', 'садовод', 'садовой', 'садовое', 'асаново', 'садов', 'садов', 'садовом']
# []
# ['получатся', 'получатся']
# ['получатся', 'получатся']
# ['натянуты', 'натянуть', 'натянута', 'натянуть', 'натянутого', 'натянуть', 'натянутого', 'натянуты', 'натянута', 'натянутого']
# []
# []
# ['естественной', 'естественной', 'естественном', 'естественное']
# []
# ['акб', 'каб', 'каабы', 'крабы', 'как', 'каб', 'каабы']
# ['очень']
# ['обе', 'общее', 'общем', 'общ', 'общей', 'общие', 'вое', 'обе', 'обыще', 'овоще']
# []
# ['рли', 'рулят', 'улити', 'рулет', 'рубли', 'улита', 'рли', 'улита', 'руи', 'рубит', 'рулет', 'улиты', 'рулят', 'рулет']
# ['гео', 'тот', 'зто', 'тою', 'рто', 'тто', 'удето', 'тох', 'тетко', 'топ', 'четой', 'тоф', 'петио', 'бто', 'метро', 'етр', 'летов', 'тпо', 'тпо', 'ивето', 'ото', 'нто', 'тод', 'веток', 'тто', 'тао', 'метро', 'тбо', 'летов', 'летно', 'фетой', 'тво', 'ато', 'рто', 'ньето', 'кто', 'ито', 'нео', 'мто', 'жетон', 'уто', 'шесто', 'ево', 'е', 'тоу', 'тож', 'что', 'веток', 'удето', 'е', 'тое', 'гто', 'тоя', 'тхо', 'жетон', 'точ', 'зто', 'кетоз', 'это', 'том', 'той', 'его', 'ело', 'хто', 'это', 'беато', 'тол', 'тоо', 'пто', 'хто', 'тео', 'шесто', 'што', 'пет', 'ета', 'тюо', 'йео', 'тэо', 'ото', 'кетоз', 'цвето', 'сетон', 'беато', 'желто']
# ['гео', 'тот', 'зто', 'тою', 'рто', 'тто', 'удето', 'тох', 'тетко', 'топ', 'четой', 'тоф', 'петио', 'бто', 'метро', 'етр', 'летов', 'тпо', 'тпо', 'ивето', 'ото', 'нто', 'тод', 'веток', 'тто', 'тао', 'метро', 'тбо', 'летов', 'летно', 'фетой', 'тво', 'ато', 'рто', 'ньето', 'кто', 'ито', 'нео', 'мто', 'жетон', 'уто', 'шесто', 'ево', 'е', 'тоу', 'тож', 'что', 'веток', 'удето', 'е', 'тое', 'гто', 'тоя', 'тхо', 'жетон', 'точ', 'зто', 'кетоз', 'это', 'том', 'той', 'его', 'ело', 'хто', 'это', 'беато', 'тол', 'тоо', 'пто', 'хто', 'тео', 'шесто', 'што', 'пет', 'ета', 'тюо', 'йео', 'тэо', 'ото', 'кетоз', 'цвето', 'сетон', 'беато', 'желто']
# ['обычный', 'обычный', 'обычный', 'обычные', 'обычные', 'обычным', 'обычных', 'обычным', 'обычных']
# ['негодным', 'негодным', 'негодных', 'негодных', 'негодным']
# ['считан', 'рассчитано', 'засчитан', 'рассчитана', 'засчитан', 'рассчитана', 'считан', 'рассчитаны']
# ['любэ', 'любя', 'люба', 'люнгбю', 'любо', 'лю', 'любя', 'люнгбю', 'любы', 'люба', 'люба', 'любы', 'лю', 'любо', 'любэ', 'люби', 'люби', 'бю']
# ['кесир', 'кеф', 'кесир', 'зефир', 'кебир', 'кесир', 'зефир', 'кеф', 'кир', 'ефи', 'кебир']
# ['оплата', 'оплата', 'оплата']
# ['инь', 'очина', 'очень', 'овчин', 'почин', 'почин', 'очень', 'инь', 'кочин', 'очина', 'очи', 'очень', 'сочин']
# ['глинтвейн', 'глинтвейн']
# ['потратит', 'потратит']
# []
# ['неприглядна', 'неприглядна', 'неприглядна']
# []
# ['канто', 'кокто', 'актов', 'каско', 'катод', 'какой', 'факто', 'лакто', 'аркто', 'кайко', 'факто', 'какое', 'какао', 'какао', 'карто', 'катон', 'окато', 'канто', 'окато', 'какой', 'каток', 'каком', 'акт', 'кто', 'кокто', 'лакто', 'акт']
# ...
# ['покажется', 'покажется', 'покажут', 'покажут', 'покажется', 'кажутся', 'кажутся']
# ['кубку', 'куска', 'кучку', 'курск', 'куски', 'куске', 'курку', 'пуску', 'куоку', 'куско', 'куоку', 'курскую', 'куклу', 'куоку', 'пуску', 'закуску', 'вкусу', 'курск', 'кукуй', 'закуску', 'куске', 'куско', 'куу', 'куска', 'куски', 'кучку', 'курскгу', 'ску', 'пуску', 'кубку']
# ['канто', 'кокто', 'актов', 'каско', 'катод', 'какой', 'факто', 'лакто', 'аркто', 'кайко', 'факто', 'какое', 'какао', 'какао', 'карто', 'катон', 'окато', 'канто', 'окато', 'какой', 'каток', 'каком', 'акт', 'кто', 'кокто', 'лакто', 'акт']
# ['тереть', 'тереть', 'теперь', 'теперь', 'терень', 'теперь', 'тепе', 'тепе']
# ['божию', 'бомжихи', 'оми', 'оми', 'бомжихи', 'божие', 'божеи', 'бомин', 'божие', 'божич', 'боями', 'божьи', 'бом', 'бомжихи', 'божий', 'божия']
# ['банкноты', 'банкноты', 'банкрота', 'банкноты', 'банкрота', 'банкрота', 'акроты', 'акроты']
# ['юю', 'юзао', 'юаню', 'тюза', 'юаню', 'сюза', 'юзао', 'зарю', 'знаю', 'знаю', 'сюза']
# ['придается', 'придается']
# ['звать', 'звать', 'знать', 'юза', 'юза']
# ['зара', 'затрат', 'завтра', 'затора', 'зара', 'завтра']
# []
# ['ирригаторов', 'ирригаторов']
# ['коломенское', 'коломенское', 'коломенское', 'коломенское']
# ['потро', 'помпо', 'помор', 'прото', 'поток', 'почто', 'потро', 'потам', 'почто', 'помог', 'порто', 'потос', 'пто', 'отомо', 'пом', 'пом', 'понто', 'потом', 'потоп', 'отомо']
# []
# ['одноклассники', 'одноклассники', 'одноклассники']
# ['долго']
# []
# []
# []
# ['соседняя', 'соседняя', 'соседняя']
# ['впечатление', 'впечатление', 'впечатление', 'впечатление']
# ['соответственное', 'соответственное']
# ['1460']
# ['полна', 'полна']
# ['чорний', 'чорний', 'оный', 'чорний', 'оный', 'сорный', 'горный', 'чёрный', 'черный', 'черный', 'сорный', 'черный', 'горный', 'чёрный']
# []
# ['вернулась']
# ['рабада', 'рабада', 'рашада', 'рашада', 'рашада']
# ['представит', 'представит', 'представ']
# ['распылены', 'распылены']
# ['возьмёшь', 'возьмёшь', 'возьмёшь']
# ['ответственностью', 'ответственностью']
# ['напишет', 'напишет', 'пишут', 'пишут', 'напишет']
# []
# ['поливе', 'оливет', 'поливает', 'оливет']
# ['душевыми', 'дешёвыми', 'душевыми', 'душевыми', 'дешёвыми', 'дешёвыми']
# []
# []
# ['планируемое', 'планируемом', 'планируемая', 'планирует', 'планируемый', 'планируемая', 'планируемом', 'планирует', 'планирует', 'планируемый', 'планируемых', 'планируемом', 'планируемую', 'планируемую']
# ['развито', 'развито', 'разви', 'разви']
# []
# ['кстати', 'костанте', 'статен', 'кате', 'сате', 'статей', 'костанте', 'сате', 'кстати', 'статье', 'кстати', 'старте', 'статуе', 'стае']
# ['како']
# ['мщина', 'мщина']
# ['волчат', 'волчат', 'молчит', 'мола', 'молчал', 'умолчать', 'волчат', 'моча', 'молчал', 'молчит', 'моча', 'умолчать', 'молчит']
# ['параллельно', 'параллельно', 'параллельно', 'параллельно']
# ['поверю', 'поверю', 'проверяя', 'проверяя', 'проверяя']
# ['татра', 'арата', 'цитрата', 'трату', 'ранта', 'штата', 'ората', 'брата', 'стратах', 'татар', 'ората', 'траты', 'утрат', 'брата', 'ата', 'рта', 'трама', 'грата', 'теракта', 'трава', 'трату', 'раста', 'ратша', 'стратам', 'татай', 'ратак', 'трама', 'татха', 'райта', 'цитрата', 'тафта', 'трапа', 'трама', 'врата', 'стратам', 'утрат', 'трала', 'татта', 'траут', 'траты', 'ратаг', 'нитрата', 'трава', 'трала', 'тратя', 'тахта', 'грата', 'тратя', 'ратае', 'трапа', 'врата', 'трактат', 'тафта', 'таранта', 'трактат']
# ['обе', 'общее', 'общем', 'общ', 'общей', 'общие', 'вое', 'обе', 'обыще', 'овоще']
# ['постарайтесь', 'постарайтесь', 'постарайтесь']
# []
# []
# ['налет', 'надет', 'нет', 'намет', 'аще', 'надет', 'намет', 'нат', 'налет', 'аще', 'знает', 'налет']
# ['абель', 'абель', 'грабитель', 'грабитель']
# ['мно', 'морга', 'многова', 'могае', 'смога', 'нгога', 'манга', 'ногам', 'ногра', 'ногат', 'много', 'ногай', 'нга', 'ногра', 'мозга', 'могла', 'мно', 'ногах', 'можга', 'многова', 'могла']
# []
# []
# ['свершением', 'совершения', 'совершения', 'свершением', 'свершением']
# []
# ['lancia', 'blanco']
# ['поше', 'поте', 'поет', 'пеше', 'полете', 'повете', 'поте']
# ['налет', 'надет', 'нет', 'намет', 'аще', 'надет', 'намет', 'нат', 'налет', 'аще', 'знает', 'налет']
# ['укладываются']
# ['тормозные']
# ['которых']
# ['поморник', 'поморник', 'поморник', 'помощник', 'помощник']
# []
# []
# ['сестри', 'сестры', 'сестры']
# ['рискнул', 'рискнул', 'рискнул']
# ['обе', 'общее', 'общем', 'общ', 'общей', 'общие', 'вое', 'обе', 'обыще', 'овоще']
# ['марином', 'марином', 'камином', 'маном', 'мамин', 'марином', 'мином', 'мамин', 'камином', 'камином']
# ['очень']
# []
# []
# ['равняться', 'равняться']
# ['счастлива', 'счастлива']
# []
# ['мягче', 'мгш', 'мягче', 'мгш', 'мягче']
# []
# []
# ['объективно', 'объективно', 'объективно']
# ['кокто', 'тто', 'тотом', 'корто', 'котто', 'котов', 'киото', 'киото', 'тоо', 'котор', 'клото', 'котто', 'кто', 'конто', 'котко', 'котор', 'тоо', 'клото', 'котон']
# ['кокто', 'тто', 'тотом', 'корто', 'котто', 'котов', 'киото', 'киото', 'тоо', 'котор', 'клото', 'котто', 'кто', 'конто', 'котко', 'котор', 'тоо', 'клото', 'котон']
# ['кокто', 'тто', 'тотом', 'корто', 'котто', 'котов', 'киото', 'киото', 'тоо', 'котор', 'клото', 'котто', 'кто', 'конто', 'котко', 'котор', 'тоо', 'клото', 'котон']
# ['естественной', 'естественной', 'естественном', 'естественное']
# ['беседня', 'беседня', 'сведя', 'ясеня', 'следя', 'средняя', 'сведя', 'седая', 'сегодня', 'средн', 'дня', 'сегодня', 'дня', 'сенья', 'седан', 'сенья', 'седан']
# ['принцип', 'принцип']
# ['применял', 'применял', 'применяя', 'применяя', 'применяя']
# ['срываясь', 'срываясь', 'срываясь']
# ['естественной', 'естественной', 'естественном', 'естественное']
# ['одиночество', 'одиночество']
# ['белым', 'блеклые', 'блеклых', 'белым', 'блеклые', 'блеклые', 'блеклых']
# ['желанием', 'желаем', 'желанием', 'желанием']
# ['просмотре', 'просмотра', 'промоутер', 'просмотре', 'просмотре', 'просмотры', 'просмотре', 'промоутер', 'просмотру']
# ['контакты', 'контакте', 'контакта', 'контакте', 'контакта', 'контакту', 'контакты', 'контракт', 'контакту', 'контактами', 'контакта']
# ['тото']
# ['естественной', 'естественной', 'естественном', 'естественное']
# ['внука', 'нудда', 'нда', 'нутка', 'кда', 'нуква', 'неуда', 'нужда', 'нужда', 'нуква', 'кнуда', 'нка', 'наука', 'нудда', 'нудда', 'снука']
# []
# ['ответьте', 'ответить', 'ответьте', 'ответь', 'ответьте', 'ответьте']
# ['адрес', 'андресу', 'аресу', 'адрес']
# []
# ['периодически', 'периодически', 'периодически']
# ['созванивается', 'созванивается', 'созванивается']
# []
# ['естественной', 'естественной', 'естественном', 'естественное']
# ['успения', 'успения']
# ['проба', 'пробках', 'пробами', 'пробках', 'проба']
# ['минутка', 'минутах', 'минутах', 'минут', 'минут']
# []
# []
# ['айл', 'май', 'майлз', 'майкл', 'майло', 'майлс', 'мал', 'айл', 'майли']
# ['знаю', 'знаю', 'незнанию', 'незнанию']
# ['следующая', 'следующая', 'следующая']
# []
# ['что']
# ['анете', 'инлет', 'инертен', 'винте', 'инлет', 'диете', 'интер', 'инеем', 'диете', 'ищете', 'минее', 'нинет', 'нее', 'инертен', 'минее', 'синее', 'ищете', 'нефте', 'винте', 'анете']
# ['нико', 'личо', 'начо', 'ничего', 'ничков', 'нидо', 'ниро', 'ниор', 'юнио', 'ничего', 'ниро', 'анио', 'начо', 'низо', 'личо', 'нико', 'личо', 'нино', 'кичо', 'ннио', 'унио', 'чо', 'низо', 'нидо', 'юнио', 'ич', 'нино', 'кичо', 'нило', 'нило']
# ['сажи', 'сажи']
# ['оказывется', 'показывается', 'доказывается', 'отказывается', 'отказывается']
# []
# ['шоколадные', 'шоколадное', 'шоколаду', 'шоколада', 'окладе', 'шоколаду', 'шоколаду', 'шоколадное', 'шоколада', 'окладе']
# ['придается', 'придается']
# ['впали', 'спали', 'совпали', 'впали', 'рвали', 'совпали']
# []
# ['связываемым', 'связывает', 'связываемым', 'связывавшем', 'связывающем', 'связывает', 'связываемое', 'связывает', 'связывавшем', 'связываемые', 'связывающем', 'связываемым']
# []
# ['когда', 'когда']
# ['заразился', 'заразился']
# ['компа', 'гомпы', 'компа', 'компу', 'коп', 'кмп', 'копны', 'компоты', 'компоты', 'помпы', 'копцы', 'коммы', 'гомпы', 'коммы', 'гомпы', 'помпы', 'кошмы', 'коп', 'копыт', 'окопы', 'кормы', 'клопы', 'скопы', 'коммы', 'космы', 'компу']
# ['пятых', 'занятых', 'занятых', 'пятых', 'занятых']
# ['вставлял', 'вставлял', 'вставлял']
# ['матерным', 'матерным', 'матерным']
# []
# []
# ['чищенный', 'чищенный', 'очищен', 'очищен']
# ['новогоднее', 'новогоднее', 'новогоднее']
# ['паря', 'упрямо', 'прямой', 'поря', 'прямых', 'прямым', 'поря', 'впрямь', 'пром', 'ям', 'пром', 'впрямь', 'перя', 'хрям', 'прямые', 'прямая', 'хрям', 'пром', 'прямая', 'прая', 'прим', 'прямой', 'прам', 'прямым', 'ям', 'прямую', 'прим', 'парням', 'прямым', 'прямую']
# []
# ['волнующее', 'волнующей', 'волнующее', 'волнующее']
# ['тесно', 'сосно', 'сосно', 'лесно', 'тесно', 'бессо', 'бессо', 'есн']
# ['ване', 'вале', 'варище', 'варище', 'чаще', 'вате', 'ваше', 'ве', 'вазе', 'ваке', 'чаще', 'ваге', 'вале', 'варе', 'вате', 'ва', 'чаще', 'васе', 'ваше', 'ваге', 'васе', 'ваке', 'ване', 'ваке', 'вазе']
# []
# ['поэтому', 'потомку', 'апотому', 'поэтому', 'потом', 'потомуж']
# ['сногсшибательной', 'сногсшибательной']
# ['делается', 'дается', 'дается']
# ['благодаря', 'благодаря']
# ['кому', 'редком', 'некому', 'седому', 'кому', 'дикому', 'редком', 'седому']
# ['аромата', 'ромау', 'ромау', 'ароматы', 'ароматы', 'аромата', 'аромата']
# ['штюбель', 'штюбель', 'абель', 'шталь', 'штабе', 'штабе', 'шталь', 'штюбель', 'абель']
# ['извините', 'извините', 'зените', 'ивенте', 'зените', 'извините', 'звенит', 'ивенте']
# ['субури', 'субуры', 'субуры']
# ['проверках', 'проверкам', 'проверках']
# ['1г']
# ['когда', 'когда']
# []
# []
# ['грянули', 'грянули', 'грянули']
# ['написать', 'написать', 'написать', 'написать']
# ['стусу', 'стаду', 'стаду', 'стасову', 'тарсу', 'эстас', 'станс', 'стану', 'стасову', 'стусу', 'талсу', 'саксу', 'саксу', 'стаса', 'стс', 'стаса', 'станс', 'ста', 'статс', 'тарсу']
# ['линия', 'линия', 'липня', 'липня', 'ливан', 'бивня', 'ливне', 'ливен', 'ливны', 'ливне', 'лия', 'ливны', 'алиня', 'вня', 'бивня', 'ливни', 'ливония', 'бивня', 'ливне', 'ливнями', 'ливия']
# ['совершенно', 'совершенно', 'совершенно']
# ['меле', 'миле', 'мызе', 'смысле', 'мгле', 'омыл', 'муле', 'мыло', 'мыке', 'мысе', 'мале', 'мыли', 'ме', 'мысе', 'хмылев', 'мале', 'мыла', 'мыли', 'млет', 'миле', 'ле', 'рыле', 'мыслей', 'меле', 'рыле', 'мыла', 'мыло', 'хмылев', 'муле', 'мгле', 'мыке', 'мыло', 'ме', 'мызе']
# []
# ['нарекает', 'нарекает', 'нарезать', 'нарезают', 'нарекает', 'нарезается', 'нарезают', 'нарезают', 'нарезается']
# []
# []
# ['нико', 'личо', 'начо', 'ничего', 'ничков', 'нидо', 'ниро', 'ниор', 'юнио', 'ничего', 'ниро', 'анио', 'начо', 'низо', 'личо', 'нико', 'личо', 'нино', 'кичо', 'ннио', 'унио', 'чо', 'низо', 'нидо', 'юнио', 'ич', 'нино', 'кичо', 'нило', 'нило']
# ['тогда', 'тогда', 'согда', 'под', 'подан', 'подач', 'богда', 'гогда', 'богда', 'когда', 'подал', 'погар', 'погодах', 'согда', 'погас', 'гда', 'плода', 'полгода', 'гогда', 'подав', 'гда', 'подаю', 'когда', 'пьода', 'подаю', 'полгода', 'погар']
# ['канто', 'кокто', 'актов', 'каско', 'катод', 'какой', 'факто', 'лакто', 'аркто', 'кайко', 'факто', 'какое', 'какао', 'какао', 'карто', 'катон', 'окато', 'канто', 'окато', 'какой', 'каток', 'каком', 'акт', 'кто', 'кокто', 'лакто', 'акт']
# []
# ['убедиться', 'учиться', 'учиться', 'убить', 'битья', 'учиться', 'убираться', 'убираться', 'убить', 'убедиться']
# ['цветником', 'великом', 'венском', 'военком', 'ником', 'венском', 'ником', 'великом', 'военком', 'великом', 'цветником', 'веном']
# []
# []
# []
# ['очень']
# ['попыталась', 'пыталась', 'пыталась', 'пыталась', 'попыталась']
# ['чувствовать', 'чувствовать', 'чувствовать', 'чувствовать']
# ['тогда', 'тогда', 'согда', 'под', 'подан', 'подач', 'богда', 'гогда', 'богда', 'когда', 'подал', 'погар', 'погодах', 'согда', 'погас', 'гда', 'плода', 'полгода', 'гогда', 'подав', 'гда', 'подаю', 'когда', 'пьода', 'подаю', 'полгода', 'погар']
# ['осенне', 'осенне']
# ['кабак', 'касак', 'ааа', 'кабак', 'капак', 'капак', 'камак', 'казак', 'казак', 'кабак', 'камак', 'кааба', 'касак']
# []
# ['поверхностно', 'поверхностно']
# []
# []
# ['воот']
# []
# []
# ['съездила', 'съезда', 'съезде', 'съездила', 'съезда']
# []
# ['кстати', 'костанте', 'статен', 'кате', 'сате', 'статей', 'костанте', 'сате', 'кстати', 'статье', 'кстати', 'старте', 'статуе', 'стае']
# []
# []
# ['очищен', 'боен', 'воен', 'олен', 'оден', 'ичен', 'опен', 'очно', 'оден', 'омен', 'отче', 'осен', 'член', 'оена', 'прочен', 'очно', 'цогчен', 'обучен', 'цогчен', 'обен', 'боен', 'овен', 'отче', 'чени', 'ичен', 'очищен', 'овен', 'моче', 'осен', 'ичен', 'омен', 'челн', 'обычен', 'ченс', 'обучен', 'прочен', 'опен']
# ['цнрм', 'центрами', 'центра', 'центре', 'центре', 'центры', 'центры', 'центры', 'центру', 'цнрм', 'центар', 'центра', 'центру']
# ['выклева', 'влево', 'валуева', 'влево', 'влова', 'левая', 'левар', 'слева', 'евлоева', 'выклева', 'лев', 'валуева', 'волевая', 'слева', 'вла', 'леава', 'левша', 'лейва', 'левда', 'лоева', 'влера', 'левка', 'леван', 'леава', 'влера', 'влера', 'вва', 'валеева']
# ['рассказ', 'рассказ', 'расскажут', 'расскажут']
# []
# []
# ['забег', 'забегам', 'забегах', 'забег', 'забегам', 'забегах']
# ['боулта', 'болт', 'бота', 'болота', 'болтай', 'болтах', 'болтай', 'бола', 'болтах', 'болтай']
# []
# ['радужным', 'радужной', 'радужное', 'радужным', 'радужное', 'радужной', 'радужной', 'радужным']
# ['маршрутка', 'машутки', 'маршруток', 'маршрут', 'маршрутка', 'машутки', 'маршрут']
# ['финна', 'финна']
# ['толкать', 'толкать', 'потолкаться', 'потолкаться']
# ['тобо', 'торной', 'торбей', 'трибой', 'трубой', 'торбей', 'торной', 'трой', 'торо', 'торбей', 'торной', 'второй']
# ['23к']
# ['придается', 'придается']
# ['некоторм', 'некоторм', 'некоторому', 'некоторыми']
# ['действ', 'действие', 'действие', 'действие', 'действие']
# []
# ['лекарствами', 'лекарствами', 'лекарствами', 'лекарство', 'лекарство']
# ['здесь', 'здесь', 'сде', 'здесь', 'спесь', 'сесть', 'смесь', 'смесь', 'сесть', 'днесь', 'сде', 'спесь']
# ['сносно', 'соосно', 'осно', 'собо', 'соосно', 'сосной', 'собо', 'сносно']
# ['мужчины', 'мужчины', 'мужчины']
# ['прямой', 'прямой', 'прямом', 'упрямо', 'прямое']
# ['зубу', 'зубы', 'зуба', 'зб', 'зу', 'зубр', 'зб']
# ['зубу', 'зубы', 'зуба', 'зб', 'зу', 'зубр', 'зб']
# ['попадет', 'пропадает', 'попадет', 'опадает', 'подпадает', 'подпадает']
# ['сизые', 'самые', 'саи', 'самые', 'самые', 'саи', 'сизые']
# ['ракето', 'като', 'ракето', 'ракето', 'како', 'како']
# ['изюминку', 'изюминку', 'изюминку']
# ['аят', 'опять', 'пятью', 'опять', 'ять', 'лаять', 'таять', 'ять']
# ['уде', 'будет', 'будде', 'беш', 'будет', 'беш', 'будем', 'будке', 'обуде', 'буш', 'уде', 'будье', 'бунде', 'блуде', 'будем']
# ['описывать', 'описывать', 'описывать']
# ['шот', 'объ', 'ушо', 'общ', 'шом', 'осб', 'оби', 'обь', 'моб', 'шорби', 'лоб', 'обд', 'шао', 'моб', 'шоп', 'шелоб', 'шок', 'шош', 'шок', 'обл', 'обе', 'шох', 'шоп', 'роб', 'боб', 'поб', 'поб', 'б', 'шоу', 'обе', 'шов', 'шуо', 'шош', 'шко', 'шох', 'шон', 'шот', 'шой', 'шелоб', 'обо', 'обв', 'коб', 'оба', 'што', 'роб', 'шой', 'шош', 'шом', 'шоу', 'боб', 'шон', 'обр']
# ['расчете', 'рассвет', 'расчете', 'рассвет', 'рассвет', 'расчеты', 'расчету', 'расчета']
# ['берет', 'берег', 'берне', 'соберем', 'выберем', 'белем', 'берег', 'берке', 'берге', 'ефрем', 'бебре', 'бером', 'бердеем', 'берге', 'бремя', 'соберем', 'керем', 'белем', 'керем', 'бером', 'береу', 'бремя', 'берум', 'берте', 'берущем', 'береу', 'берегам', 'брема', 'берет', 'бее', 'выберем', 'бреме', 'бердеем', 'бером', 'бедре', 'керем']
# ['нико', 'личо', 'начо', 'ничего', 'ничков', 'нидо', 'ниро', 'ниор', 'юнио', 'ничего', 'ниро', 'анио', 'начо', 'низо', 'личо', 'нико', 'личо', 'нино', 'кичо', 'ннио', 'унио', 'чо', 'низо', 'нидо', 'юнио', 'ич', 'нино', 'кичо', 'нило', 'нило']
# []
# []
# []
# ['пусть', 'пусть', 'пусть']
# []
# ['прочла', 'почитала', 'прочитал', 'прочитал', 'прочла']
# ['прочитавший', 'прочитавший', 'прочитавшей', 'прочитавшей']
# []
# ['чечень', 'чечень']
# ['нику', 'иуде', 'никуда', 'ниде', 'нику', 'иуде', 'никуда']
# ['дерется', 'дерется', 'дерется']
# ['неожиданном', 'неожиданное', 'неожиданное', 'неожиданной']
# ['подворотнями', 'подворотнями']
# []
# ['прекратит', 'прекратит']
# ['сосно', 'сосно']
# ['готовя', 'готовиться', 'готовиться', 'готовя']
# []
# ['квартирке', 'квартирке', 'квартирке', 'квартир']
# ['тото']
# []
# []
# ['обе', 'общее', 'общем', 'общ', 'общей', 'общие', 'вое', 'обе', 'обыще', 'овоще']
# []

# %%
print(correct/total)
print(mistaken_fixed/total_mistaken)
print(correct_broken/total_correct)
# Out:
# 0.8419209604802401
# 0.18711180124223603
# 0.06121511427586999

# %% [markdown]
# Прирост качества получился незначительным, зато я постарался исправить кажущуюся некорректность
